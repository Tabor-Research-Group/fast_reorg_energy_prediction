# %% [markdown]
# # This is the notebook for QM9 curation in the manscript
# QM9 dataset was downloaded from http://quantum-machine.org/datasets/, which uncharacterized.txt, gdb17_qm9_energy.smi, and atomref.txt in the notebook were extracted from.

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from tqdm.notebook import tqdm
from collections import defaultdict
from pysmiles import read_smiles
from openbabel import pybel
import networkx as nx
import re
print(rdkit.__version__)
# Out:
# 2022.03.2

# %%
# Canonicalize SMILES string
def canon_smi(smi):
    mol = Chem.MolFromSmiles(smi)
    Chem.SanitizeMol(mol)
    smi = Chem.MolToSmiles(mol)
    
    return smi

# %% [markdown]
# ## 1. Remove “uncharacterized molecules” defined in the original QM9 paper.
# ## 2. Remove molecules that failed RDKit SMILES canonicalization from SMILES provided by the original QM9 paper after DFT optimization.

# %%
# Build uncharacterized molecules indicated in the original QM9 paper with canonicalized SMILES 
with open('./uncharacterized.txt','r') as uc:
    uncha = list()
    for line in uc:
        line = line.rstrip().split()
        if len(line) > 2:
            if line[0].isdigit():
                uncha.append(line[1])
len(uncha)
# Out:
# 3054

# %%
# Build mol dict from QM9 with key=canon_smi, value={parsed_smi,energy}
with open('./gdb17_qm9_energy.smi','r') as qm9:
    qm9_dict = defaultdict(list)
    for line in tqdm(qm9, total=133885):
        try:
            line = line.rstrip().split()
            gdb_smi = line[1]
            parsed_smi = line[2]
            c_smi = canon_smi(parsed_smi)
            if gdb_smi in uncha:
                continue
            energy = float(line[3])
            qm9_dict[canon_smi(gdb_smi)].append({'parsed_smi':c_smi,'energy':energy})
        except:
            print(line)
# Out:
#   0%|          | 0/133885 [00:00<?, ?it/s]
# [10:33:37] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:37] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:37] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:37] Explicit valence for atom # 3 N, 4, is greater than permitted
# ['000271', '[NH3+]CCC([O-])=O', '[NH3]CCC(=O)[O]', '-323.582949']
# ['000282', 'NC(=[NH2+])C([O-])=O', 'NC(=[NH2])C(=O)[O]', '-338.530072']
# ['001117', 'NC(=[NH2+])CC([O-])=O', 'NC(=[NH2])[CH2].C(=O)=O', '-377.830859']
# ['001642', 'C[NH+]=C(N)C([O-])=O', 'CNC(=[NH2])C(=O)[O]', '-377.816466']
# ['001648', 'CNC(=[NH2+])C([O-])=O', 'CNC(=[NH2])C(=O)[O]', '-377.816463']
# ['001670', 'CC(C[NH3+])C([O-])=O', 'C[C@@H](C[NH3])C(=O)[O]', '-362.87621']
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:38] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:38] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# [10:33:38] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:38] Explicit valence for atom # 7 N, 4, is greater than permitted
# ['003828', 'N=C1C=CNN=N1', '[NH]c1cc[nH]nn1', '-335.586914']
# ['003832', 'N=C1C=NNN=C1', '[NH]c1cn[nH]nc1', '-335.590859']
# ['003833', 'N=C1C=NNN=N1', '[NH]c1cn[nH]nn1', '-351.615495']
# ['003842', 'N=C1NN=CC=N1', '[NH]c1[nH]nccn1', '-335.61837']
# ['003843', 'N=C1NN=CN=C1', '[NH]c1[nH]ncnc1', '-335.613384']
# ['003844', 'N=C1NN=NC=C1', '[NH]c1[nH]nncc1', '-335.591582']
# ['003845', 'N=C1NN=NC=N1', '[NH]c1[nH]nncn1', '-351.646368']
# ['004015', 'C[NH2+]CC(CO)=N[O-]', 'C[NH2]C[C](CO)[N][O]', '-418.138616']
# ['004018', 'NC(=[NH2+])C(=N[O-])C#N', '[NH2]=C(N)C(=N[O])C#N', '-410.814514']
# ['004019', 'NC(=[NH2+])C(C=O)=N[O-]', '[NH2]=C(N)C(=N[O])C=O', '-431.877352']
# ['004028', 'NC(=[NH2+])C(CO)=N[O-]', '[NH2]=C(N)C(=N[O])CO', '-433.071644']
# ['004419', 'OC1=CN=CC(=N)N1', 'Oc1cncc([NH])[nH]1', '-394.814053']
# ['004427', 'OC1=NC=NC(=O)O1', 'OC(=O)[N]C=[N]=C=O', '-450.668952']
# ['005804', 'CC(C)([NH3+])CC([O-])=O', 'CC(C)([NH3])CC(=O)[O]', '-402.176006']
# ['006033', 'CC(C)(C[NH3+])C([O-])=O', 'CC(C)(C[NH3])C(=O)[O]', '-402.168382']
# ['006059', 'NC(=[NH2+])C#CC([O-])=O', '[NH2]=C(N)C#CC(=O)[O]', '-414.632712']
# ['006075', 'NC(=[NH2+])OCC([O-])=O', 'NC(=[NH2])OCC(=O)[O]', '-452.987506']
# ['006170', 'CC1([NH3+])CC1C([O-])=O', 'C[C@@]1([NH3])C[C@H]1C(=O)[O]', '-400.946882']
# ['006330', 'C[NH+]=C(N)CC([O-])=O', 'CNC(=[NH2])[CH2].C(=O)=O', '-417.109311']
# ['006346', 'CNC(=[NH2+])CC([O-])=O', 'CNC(=[NH2])[CH2].C(=O)=O', '-417.110282']
# ['006683', '[O-]C(=O)CCNC=[NH2+]', '[O]C(=O)CCNC=[NH2]', '-417.034102']
# [10:33:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:39] Explicit valence for atom # 4 N, 4, is greater than permitted
# ['007245', '[O-]C(=O)C(=N)NC=[NH2+]', 'O=C(O)C(=[N]=CN)[NH]', '-431.95542']
# ['007326', 'CCNC(=[NH2+])C([O-])=O', 'CCNC(=[NH2])C(=O)[O]', '-417.108035']
# ['007335', 'C[NH2+]CC(=O)C([O-])=O', 'C[NH2]CC(=O)C(=O)[O]', '-436.91929']
# ['007375', 'C[NH2+]CC(C)C([O-])=O', 'C[NH2]C[C@@H](C)C(=O)[O]', '-402.163264']
# ['007410', 'CC(C(N)=[NH2+])C([O-])=O', 'C[CH]C(=[NH2])N.C(=O)=O', '-417.121047']
# ['007417', 'NC(=[NH2+])C(O)C([O-])=O', '[NH2]=C(N)[CH]O.C(=O)=O', '-453.04302']
# ['007419', 'NC(C(N)=[NH2+])C([O-])=O', 'N[CH]C(=[NH2])N.C(=O)=O', '-433.166605']
# ['007429', 'CN(C)C(=[NH2+])C([O-])=O', 'CN(C)C(=[NH2])C(=O)[O]', '-417.091698']
# ['007602', 'CC1(CC1[NH3+])C([O-])=O', 'C[C@]1(C[C@H]1[NH3])C(=O)[O]', '-400.944569']
# ['007654', 'C[NH+]1CC(C1)C([O-])=O', 'C[NH]1CC(C1)C(=O)[O]', '-400.962216']
# ['007657', '[NH3+]C1CC(C1)C([O-])=O', '[NH3][C@H]1C[C@@H](C1)C(=O)[O]', '-400.937791']
# ['008398', '[O-]C(=O)C12CC(C1)[NH2+]2', 'O=C([O])[C@@]12C[C@@H](C1)[NH2]2', '-399.729422']
# ['009986', '[NH2+]=CN[C-](C#N)C#N', '[NH2]=C[NH]=C(C#N)C#N', '-373.693699']
# ['010016', 'NC=[NH+][C-](C#N)C#N', '[NH2]=C[NH]=C(C#N)C#N', '-373.693699']
# ['010239', 'NC(=[NH2+])[C-](C#C)C#N', 'NC(=[NH2])[C](C#C)C#N', '-357.643536']
# ['010240', 'NC(=[NH2+])[C-](C#N)C#N', '[NH2]=C(N)[C](C#N)C#N', '-373.750386']
# ['010349', 'COC(C[NH3+])C([O-])=O', 'CO[C@@H](C[NH3])C(=O)[O]', '-438.088977']
# [10:33:40] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:40] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:40] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:40] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:40] Explicit valence for atom # 3 N, 4, is greater than permitted
# ['013805', '[NH3+]CC1CC1C([O-])=O', '[NH3][CH][C@H]1C[C@H]1C(=O)O', '-400.93789']
# ['013833', '[O-]C(=O)C1=CC[NH2+]C1', 'O=C([O])C1=CC[NH2]C1', '-399.769262']
# ['014121', '[O-]C(=O)C12CC1[NH2+]C2', '[O]C(=O)[C@]12C[C@H]1[NH2]C2', '-399.730154']
# ['014318', 'O=C1[CH-][NH+]2CCC2=C1', 'O=C1[CH][N@H]2CC[C]2[CH]1', '-362.595893']
# ['015512', 'O=C[C-]1[NH2+]CCC1=O', 'O=C[C]1[NH2]CCC1=O', '-399.786072']
# [10:33:41] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:41] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:41] Explicit valence for atom # 4 N, 4, is greater than permitted
# ['017808', '[O-]C(=O)C1C2CC1[NH2+]2', 'O=C([O])[C@H]1[C@H]2C[C@@H]1[NH2]2', '-399.708212']
# ['017809', '[O-]C(=O)C1C2C[NH+]1C2', '[O]C(=O)[C@H]1[C@H]2C[N@@H]1C2', '-399.712852']
# ['018308', 'O=C1C=C[NH+]2CC[C-]12', 'O=C1C=C[NH]2CC[C]12', '-362.598243']
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 6 7
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 3 5 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# ['020630', 'CC1=CC(=N)N=NN1', 'Cc1cc([NH])nn[nH]1', '-374.885658']
# ['020633', 'CC1=CC(=N)NN=N1', 'Cc1cc([NH])[nH]nn1', '-374.890167']
# ['020662', 'CC1=CN=NNC1=N', 'Cc1cnn[nH]c1[NH]', '-374.890327']
# ['020671', 'CC1=CNN=NC1=N', 'Cc1c[nH]nnc1[NH]', '-374.884952']
# ['020684', 'CC1=NC(=N)NN=C1', 'Cc1nc([NH])[nH]nc1', '-374.911111']
# ['020685', 'CC1=NC(=N)NN=N1', 'Cc1nc([NH])[nH]nn1', '-390.94078']
# ['020703', 'CC1=NC=NNC1=N', 'Cc1ncn[nH]c1[NH]', '-374.915104']
# ['020717', 'CC1=NNC(=N)C=N1', 'Cc1n[nH]c([NH])cn1', '-374.913693']
# ['020718', 'CC1=NNC(=N)N=C1', 'Cc1n[nH]c([NH])nc1', '-374.915497']
# ['020745', 'CC1=NNN=CC1=N', 'Cc1n[nH]ncc1[NH]', '-374.891074']
# ['020746', 'CC1=NNN=NC1=N', 'Cc1n[nH]nnc1[NH]', '-390.917213']
# ['021010', 'CN1C=CC(=N)N=N1', 'Cn1ccc([NH])nn1', '-374.874846']
# ['021060', 'CN1N=CC(=N)C=N1', 'Cn1ncc([NH])cn1', '-374.879249']
# ['021061', 'CN1N=CC(=N)N=N1', 'Cn1ncc([NH])nn1', '-390.905004']
# ['021083', 'CN1N=CC=NC1=N', 'Cn1nccnc1[NH]', '-374.907536']
# ['021089', 'CN1N=CN=CC1=N', 'Cn1ncncc1[NH]', '-374.904515']
# ['021110', 'CN1N=NC=CC1=N', 'Cn1nnccc1[NH]', '-374.883417']
# ['021112', 'CN1N=NC=NC1=N', 'Cn1nncnc1[NH]', '-390.937173']
# ['021117', 'CN=C1C=CNN=N1', 'C[N]c1cc[nH]nn1', '-374.868767']
# ['021121', 'CN=C1C=NNN=C1', 'C[N]c1cn[nH]nc1', '-374.87341']
# ['021122', 'CN=C1C=NNN=N1', 'C[N]c1cn[nH]nn1', '-390.898753']
# ['021134', 'CN=C1NN=CC=N1', 'C[N]c1[nH]nccn1', '-374.900236']
# ['021135', 'CN=C1NN=CN=C1', 'C[N]c1[nH]ncnc1', '-374.897497']
# ['021136', 'CN=C1NN=NC=C1', 'C[N]c1[nH]nncc1', '-374.874939']
# ['021137', 'CN=C1NN=NC=N1', 'C[N]c1[nH]nncn1', '-390.928902']
# ['021405', 'N=C1NC(=O)NN=C1', '[NH]c1[nH]c(=O)[nH]nc1', '-410.883197']
# ['021406', 'N=C1NC(=O)NN=N1', '[NH]c1[nH]c(=O)[nH]nn1', '-426.909328']
# ['021408', 'N=C1NC(=O)ON=N1', '[NH]c1[nH]c(=O)onn1', '-446.762348']
# ['021426', 'N=C1OC(=O)NN=C1', '[NH]c1oc(=O)[nH]nc1', '-430.750224']
# ['021427', 'N=C1OC(=O)NN=N1', '[NH]c1oc(=O)[nH]nn1', '-446.771668']
# ['021479', 'NC(=[NH2+])C1=CN=N[N-]1', 'NC(=[NH2])c1cnnn1', '-390.960036']
# ['021484', 'NC(=[NH2+])C1=NC=N[N-]1', '[NH2]=C(N)c1ncnn1', '-390.989717']
# ['021554', 'NC1=CC(=N)N=NN1', 'Nc1cc([NH])nn[nH]1', '-390.935539']
# ['021557', 'NC1=CC(=N)NN=N1', 'Nc1cc([NH])[nH]nn1', '-390.947071']
# ['021588', 'NC1=CN=NNC1=N', 'Nc1cnn[nH]c1[NH]', '-390.949452']
# ['021596', 'NC1=CNN=CC1=N', 'Nc1c[nH]ncc1[NH]', '-374.91132']
# ['021598', 'NC1=CNN=NC1=N', 'Nc1c[nH]nnc1[NH]', '-390.939269']
# ['021608', 'NC1=[NH+]C(=N)C=N[N-]1', 'Nc1[nH]c([NH])cnn1', '-390.972789']
# ['021612', 'NC1=NC(=N)NN=N1', 'Nc1nc([NH])[nH]nn1', '-407.016376']
# ['021630', 'NC1=NC=NNC1=N', 'Nc1ncn[nH]c1[NH]', '-390.985319']
# ['021644', 'NC1=NNC(=N)C=N1', 'Nc1n[nH]c([NH])cn1', '-390.967383']
# ['021645', 'NC1=NNC(=N)N=C1', 'Nc1n[nH]c([NH])nc1', '-390.965469']
# ['021669', 'NC1=NNN=CC1=N', 'Nc1n[nH]ncc1[NH]', '-390.952586']
# ['021670', 'NC1=NNN=NC1=N', 'Nc1n[nH]nnc1[NH]', '-406.98143']
# ['021703', 'NC=[NH+]C1=CN=N[N-]1', '[NH2]=CNc1cnnn1', '-390.917001']
# ['021706', 'NC=[NH+]C1=NC=N[N-]1', '[NH2]=CNc1ncnn1', '-390.950251']
# ['021856', 'OC1=CC(=N)N=NN1', 'Oc1cc([NH])nn[nH]1', '-410.808117']
# ['021871', 'OC1=NC(=N)NN=N1', 'Oc1nc([NH])[nH]nn1', '-426.888694']
# ['021878', 'OC1=NC=NNC1=N', 'Oc1ncn[nH]c1[NH]', '-410.852385']
# ['021891', 'OC1=NNC(=N)C=N1', 'Oc1n[nH]c([NH])cn1', '-410.844351']
# ['022054', 'CC(=N[O-])C#CC(N)=[NH2+]', 'C[C]([N][O])C#CC(=[NH2])N', '-433.987326']
# ['022116', 'C[NH+](C)CC(CO)=N[O-]', 'C[NH](C)C[C](CO)[N][O]', '-457.425547']
# ['022195', 'C[NH2+]CC(CC#N)=N[O-]', 'C[NH2]CC(=N[O])CC#N', '-435.173912']
# ['022203', 'C[NH2+]CC(COC)=N[O-]', 'C[NH2]CC(=N[O])COC', '-457.416845']
# ['022209', 'NC(=[NH2+])C(CC#C)=N[O-]', 'NC(=[NH2])C(=N[O])CC#C', '-433.99277']
# ['022210', 'NC(=[NH2+])C(CC#N)=N[O-]', 'NC(=[NH2])C(=N[O])CC#N', '-450.101916']
# ['022213', 'NC(=[NH2+])C(CC=O)=N[O-]', 'NC(=[NH2])C(=N[O])CC=O', '-471.177183']
# ['022232', 'C[NH2+]CC(=NO)C([O-])=O', 'C[NH2]CC(=NO)C(=O)[O]', '-492.198403']
# ['022233', 'COCC(=N[O-])C(N)=[NH2+]', 'COCC(=N[O])C(=[NH2])N', '-472.355705']
# ['022238', 'C[NH2+]CC(=N[O-])C(C)O', 'C[NH2]CC(=N[O])[C@@H](C)O', '-457.431629']
# ['022247', 'CC(=O)C(=N[O-])C(N)=[NH2+]', 'CC(=O)C(=N[O])C(=[NH2])N', '-471.207413']
# ['022248', 'NC(=[NH2+])C(=N[O-])C(N)=O', 'NC(=[NH2])C(=N[O])C(=O)N', '-487.278337']
# ['022253', 'CC(O)C(=N[O-])C(N)=[NH2+]', 'C[C@@H](O)C(=N[O])C(=[NH2])N', '-472.367608']
# [10:33:42] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:42] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5
# [10:33:42] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 7
# [10:33:42] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 6 7 8
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 6
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 3 4 7 8
# [10:33:43] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# ['022438', 'C[NH+]=C(N)C(C=O)=N[O-]', 'CNC(=[NH2])C(=N[O])C=O', '-471.16096']
# ['022439', 'CNC(=[NH2+])C(=N[O-])C#N', 'CNC(=[NH2])C(=N[O])C#N', '-450.098345']
# ['022441', 'CNC(=[NH2+])C(C=O)=N[O-]', 'CNC(=[NH2])C(=N[O])C=O', '-471.160959']
# ['022443', 'CNC(=[NH2+])C(CO)=N[O-]', 'CNC(=[NH2])C(=N[O])CO', '-472.353931']
# ['022444', 'C[NH+]=C(N)C(CO)=N[O-]', 'CNC(=[NH2])C(=N[O])CO', '-472.353932']
# ['022460', 'C[NH2+]C(C)C(CO)=N[O-]', 'C[NH2][C@@H](C)[C](CO)[N][O]', '-457.431408']
# ['022482', 'NC=[NH+]CC(CO)=N[O-]', '[NH2]=CNC[C](CO)[N][O]', '-472.294853']
# ['022495', 'C[NH2+]CCC(=N[O-])C#N', 'C[NH2]CCC(=N[O])C#N', '-435.139327']
# ['022504', 'CC[NH2+]CC(CO)=N[O-]', 'CC[NH2]C[C](CO)[N][O]', '-457.430588']
# ['022686', 'OCC(CC1C[NH2+]1)=N[O-]', 'OCC(=N[O])C[C@H]1C[NH2]1', '-456.202959']
# ['022974', '[O-]N=C(C=O)C1C[NH2+]C1', '[O]N=C(C=O)C1C[NH2]C1', '-455.009993']
# ['022980', 'OCC(=N[O-])C1C[NH2+]C1', 'OC[C]([N][O])C1C[NH2]C1', '-456.202281']
# ['023150', 'C[NH2+]CC(=N[O-])C1CO1', 'C[NH2]CC(=N[O])[C@H]1CO1', '-456.206824']
# ['023364', 'NC(=[NH2+])C(=N[O-])C1CN1', 'NC(=[NH2])C(=N[O])[C@H]1CN1', '-451.249106']
# ['023365', 'NC(=[NH2+])C(=N[O-])C1CO1', 'NC(=[NH2])C(=N[O])[C@H]1CO1', '-471.137692']
# ['023372', 'CC(=N[O-])C(O)C1C[NH2+]1', 'CC(=N[O])[C@@H](O)[C@H]1C[NH2]1', '-456.184464']
# ['023690', 'FC1=CN=CC(=N)N1', 'Fc1cncc([NH])[nH]1', '-418.832387']
# ['023700', 'FC1=NC=NC(=O)O1', 'FC(=O)[N]C=[N]=C=O', '-474.686144']
# ['023792', 'FC1=CC(=N)N=NN1', 'Fc1cc([NH])nn[nH]1', '-434.831863']
# ['023795', 'FC1=CC(=N)NN=N1', 'Fc1cc([NH])[nH]nn1', '-434.840291']
# ['023810', 'FC1=CN=NNC1=N', 'Fc1cnn[nH]c1[NH]', '-434.832526']
# ['023815', 'FC1=CNN=NC1=N', 'Fc1c[nH]nnc1[NH]', '-434.825781']
# ['023820', 'FC1=NC(=N)C=NN1', 'Fc1nc([NH])cn[nH]1', '-434.87396']
# ['023823', 'FC1=NC(=N)NN=C1', 'Fc1nc([NH])[nH]nc1', '-434.875071']
# ['023824', 'FC1=NC(=N)NN=N1', 'Fc1nc([NH])[nH]nn1', '-450.902794']
# ['023840', 'FC1=NNC(=N)C=N1', 'Fc1n[nH]c([NH])cn1', '-434.862871']
# ['024872', 'N=C1NC(=CN=C1)C#C', '[NH]c1[nH]c(cnc1)C#C', '-395.728388']
# ['024873', 'N=C1NC(=CN=C1)C#N', '[NH]c1[nH]c(cnc1)C#N', '-411.828113']
# ['025041', 'N=C1NC=C(N=C1)C#C', '[NH]c1[nH]cc(nc1)C#C', '-395.728418']
# ['025042', 'N=C1NC=C(N=C1)C#N', '[NH]c1[nH]cc(nc1)C#N', '-411.833415']
# ['025164', 'N=C1NC=CN=C1C#N', '[NH]c1[nH]ccnc1C#N', '-411.831124']
# ['025382', 'N=C1NC(C=O)=CN=C1', '[NH]c1[nH]c(C=O)cnc1', '-432.910612']
# ['025400', 'N=C1NC=CN=C1C=O', '[NH]c1[nH]ccnc1C=O', '-432.897165']
# ['025411', 'N=C1NC=C(C=O)N=C1', '[NH]c1[nH]cc(C=O)nc1', '-432.908721']
# ['025531', '[NH2+]=CNC1=COC(=O)[N-]1', '[NH2]=CNc1coc(=O)n1', '-470.015496']
# ['025732', 'NC(=[NH2+])C1=C([O-])C=CN1', 'NC(=[NH2])[C]1C(=O)C=CN1', '-434.117808']
# ['025733', 'NC(=[NH2+])C1=C([O-])N=CN1', 'NC(=[NH2])[C]1C(=O)N=CN1', '-450.182708']
# [10:33:43] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:43] Can't kekulize mol.  Unkekulized atoms: 1 2 5 7 8
# [10:33:43] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:43] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 7
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 6
# [10:33:44] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 3 5 6 7
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 7
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 4 6 7 8
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:44] Explicit valence for atom # 4 N, 4, is greater than permitted
# ['025758', 'NC(=[NH2+])C1=C([O-])OC=C1', '[NH2]=C(N)[C]1C(=O)OC=C1', '-454.012997']
# ['025759', 'NC(=[NH2+])C1=C([O-])OC=N1', '[NH2]=C(N)[C]1C(=O)OC=N1', '-470.081061']
# ['025815', 'NC(=[NH2+])C1=CC=C([O-])N1', 'NC(=[NH2])[C]1C=CC(=O)N1', '-434.12012']
# ['025816', 'NC(=[NH2+])C1=CC=C([O-])O1', 'NC(=[NH2])[C]1C=CC(=O)O1', '-454.004009']
# ['025818', 'NC(=[NH2+])C1=CN=C(O)[N-]1', 'NC(=[NH2])c1cnc(O)n1', '-450.178621']
# ['025821', 'NC(=[NH2+])C1=NC=C([O-])N1', 'NC(=[NH2])[C]1N=CC(=O)N1', '-450.1801']
# ['025859', 'NC(=[NH2+])C1=C[N-]C(=N)O1', 'NC(=[NH2])c1cnc([NH])o1', '-450.156709']
# ['025860', 'NC(=[NH2+])C1=CNC(=O)[N-]1', 'NC(=[NH2])c1c[nH]c(=O)n1', '-450.172331']
# ['025861', 'NC(=[NH2+])C1=COC(=N)[N-]1', '[NH2]=C(N)C(=N[C][NH])C=O', '-450.155649']
# ['025862', 'NC(=[NH2+])C1=COC(=O)[N-]1', 'NC(=[NH2])[C](C=O)N=C=O', '-470.066525']
# ['025886', 'NC(=[NH2+])C1=COC([O-])=C1', 'NC(=[NH2])[C](C=O)[CH][C][O]', '-453.976034']
# ['025915', 'NC(=[NH2+])N1C=CC([O-])=C1', 'NC(=[NH2])N1C=CC(=O)[CH]1', '-434.060449']
# ['026881', 'CC1=C(O)NC(=N)C=N1', 'Cc1c(O)[nH]c([NH])cn1', '-434.103964']
# ['027272', '[O-]C1=C2C[NH2+]CC2=CO1', 'O=C1[C]2C[NH2]CC2=CO1', '-437.853279']
# ['027871', 'OC1=NC(O)=NC(=O)O1', 'OC(=O)[N]C(=[N]=C=O)O', '-525.910186']
# ['028083', '[O-]C1=CC(NC=[NH2+])=CO1', 'O=C1[CH]C(=CO1)NC=[NH2]', '-453.928727']
# ['028251', '[O-]C1=CC2=C(C[NH2+]C2)O1', 'O=C1[CH]C2=C(C[NH2]C2)O1', '-437.84818']
# ['028359', 'CC1=CN=C(O)C(=N)N1', 'Cc1cnc(O)c([NH])[nH]1', '-434.122502']
# ['028378', 'CC1=NC=C(O)NC1=N', 'Cc1ncc(O)[nH]c1[NH]', '-434.10877']
# ['028393', 'NC1=CN=C(O)C(=N)N1', 'Nc1cnc(O)c([NH])[nH]1', '-450.169806']
# ['028408', 'OC1=CN=C(O)C(=N)N1', 'Oc1cnc(O)c([NH])[nH]1', '-470.048723']
# ['029540', '[O-]C1=COC2=C1C[NH2+]C2', 'O=C1[CH]OC2=C1C[NH2]C2', '-437.810259']
# ['029625', 'CN1C(=N)C=NC=C1O', 'Cn1c([NH])cncc1O', '-434.098583']
# ['029825', 'CN1C=C(O)N=CC1=N', 'Cn1cc(O)ncc1[NH]', '-434.098448']
# ['030045', 'CN1C=CN=C(O)C1=N', 'Cn1ccnc(O)c1[NH]', '-434.111361']
# ['030436', 'CN=C1NC(O)=CN=C1', 'C[N]c1[nH]c(O)cnc1', '-434.094624']
# ['030505', 'CN=C1NC=CN=C1O', 'C[N]c1[nH]ccnc1O', '-434.101349']
# ['030526', 'NC=[NH+]C1=C([O-])C=CN1', '[NH2]=CN[C]1C(=O)C=CN1', '-434.059526']
# ['030527', 'NC=[NH+]C1=C([O-])C=CO1', '[NH2]=CN[C]1C(=O)C=CO1', '-453.934267']
# ['030529', 'NC=[NH+]C1=C([O-])OC=C1', '[NH2]=CN[C]1C(=O)OC=C1', '-453.957598']
# ['030530', 'NC=[NH+]C1=C([O-])OC=N1', '[NH2]=CN[C]1C(=O)OC=N1', '-470.025774']
# ['030538', 'NC=[NH+]C1=CC=C([O-])O1', '[NH2]=CNC1=C[CH]C(=O)O1', '-453.951698']
# ['030540', 'NC=[NH+]C1=CN=C(O)[N-]1', '[NH2]=CNc1cnc(O)n1', '-450.130112']
# ['030546', 'NC=[NH+]C1=C[N-]C(=N)O1', '[NH2]=CNc1cnc([NH])o1', '-450.104325']
# ['030547', 'NC=[NH+]C1=COC(=N)[N-]1', '[NH2]=CNc1coc([NH])n1', '-450.101956']
# ['030549', 'NC=[NH+]C1=COC(=O)[N-]1', '[NH2]=CNc1coc(=O)n1', '-470.015495']
# ['030551', 'NC=[NH+]C1=COC([O-])=C1', '[NH2]=CNC1=COC(=O)[CH]1', '-453.928728']
# ['030552', 'NC=[NH+]C1=COC([O-])=N1', '[NH2]=CNc1coc(=O)n1', '-470.004996']
# ['030761', 'NC1=C(C[NH3+])OC=C1[O-]', 'NC1=C(C[NH3])O[CH]C1=O', '-455.08104']
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:44] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:33:45] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:45] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:45] Explicit valence for atom # 7 N, 4, is greater than permitted
# ['032041', 'COC1=CN=CC(=N)N1', 'COc1cncc([NH])[nH]1', '-434.086651']
# ['032059', 'OCC1=CN=CC(=N)N1', 'OCc1cncc([NH])[nH]1', '-434.090666']
# ['032414', 'CC1=C([O-])OC=C1C[NH3+]', 'C[C]1C(=O)OC=C1C[NH3]', '-439.048303']
# ['032465', '[NH3+]CC1=COC([O-])=C1O', '[NH3]CC1=C(C(=O)O[CH]1)O', '-474.978895']
# ['033400', 'N#C[C-](C#N)C1C[NH2+]C1', 'N#C[C](C#N)C1C[NH2]C1', '-396.87678']
# [10:33:47] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:48] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:48] Explicit valence for atom # 8 N, 4, is greater than permitted
# ['042424', 'O=C([N-]C1C[NH2+]C1)C#N', 'O=C([N]C1C[NH2]C1)C#N', '-434.016751']
# ['043213', 'O=C1C2[NH2+]CC2[C-]1C#N', 'O=C1[C@H]2[NH2]C[C@H]2[C]1C#N', '-416.754086']
# ['043475', 'O=C1[CH-]C(=O)C2CC1[NH2+]2', 'O=C1[CH]C(=O)[C@@H]2C[C@H]1[NH2]2', '-437.865832']
# [10:33:48] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:48] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:48] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:48] Explicit valence for atom # 7 N, 4, is greater than permitted
# ['045541', 'O=C1[CH-][NH+]2CCCC2=C1', 'O=C1[CH][N@H]2CCC[C]2[CH]1', '-401.919634']
# ['045545', 'O=C1O[C-]2CC[NH2+]C2=C1', '[O][C][CH][C]1C(=O)CC[NH2]1', '-437.858166']
# ['045546', 'O=C1O[C-]2C[NH2+]CC2=C1', 'O=C1OC2=C(C[NH2]C2)[CH]1', '-437.848179']
# ['046611', 'O=C1[CH-]NC2=C1C[NH2+]C2', 'O=C1[CH]NC2=C1C[NH2]C2', '-417.939084']
# [10:33:49] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:49] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:49] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# ['049723', 'O=C[C-]1C2C[NH2+]C2C1=O', 'O=C[C]1[C@H]2C[NH2][C@H]2C1=O', '-437.823164']
# ['050309', 'O=C[C-]1[NH2+]C2CC2C1=O', 'O=C[C]1[NH2][C@H]2C[C@H]2C1=O', '-437.851752']
# ['050620', 'O=C[C-]1[NH2+]CC=CC1=O', 'O=C[C]1[NH2]CC=CC1=O', '-437.867237']
# ['050736', 'O=C[C-]1CC[NH2+]CC1=O', 'O=C[C]1CC[NH2]CC1=O', '-439.055296']
# ['051246', '[NH2+]=CNC1=CC(=O)N[CH-]1', '[NH2]=CNC1=CNC(=O)[CH]1', '-434.057513']
# ['051247', '[NH2+]=CNC1=CC(=O)O[CH-]1', '[NH2]=CNC1=COC(=O)[CH]1', '-453.928733']
# ['052579', 'CC#C[C-](C#N)C(N)=[NH2+]', 'CC#C[C](C#N)C(=[NH2])N', '-396.943238']
# ['053821', '[O-]C(=O)C(=O)C1CC[NH2+]1', 'O=C([O])C(=O)[C@H]1CC[NH2]1', '-474.997087']
# ['053845', '[O-]C(=O)C(=[NH2+])NC1CC1', '[O]C(=O)C(=[NH2])NC1CC1', '-455.172789']
# ['053892', '[O-]C(=O)C(=O)CNC=[NH2+]', 'O=C([O])C(=O)CNC=[NH2]', '-491.080227']
# ['053896', 'NC(=[NH2+])C(C#C)C([O-])=O', 'NC(=[NH2])[CH]C#C.C(=O)=O', '-453.981069']
# ['053897', 'NC(=[NH2+])[C-](C#N)C(N)=O', 'NC(=[NH2])[C](C#N)C(=O)N', '-450.209037']
# ['053939', 'CC(C)(C(N)=[NH2+])C([O-])=O', 'C[C](C)C(=[NH2])N.C(=O)=O', '-456.410898']
# ['053941', 'CC(N)(C(N)=[NH2+])C([O-])=O', 'C[C](N)C(=[NH2])N.C(=O)=O', '-472.453268']
# ['053943', 'CC([NH3+])(C(N)=O)C([O-])=O', 'C[C]([NH3])C(=O)N.C(=O)=O', '-492.305632']
# ['053944', 'CC(O)(C(N)=[NH2+])C([O-])=O', 'C[C](O)C(=[NH2])N.C(=O)=O', '-492.337307']
# ['054071', 'NC(=[NH2+])[C-](OC=N)C#N', 'NC(=[NH2])[C](O[CH][NH])C#N', '-450.137281']
# ['054072', 'NC(=[NH2+])[C-](OC=O)C#N', 'NC(=[NH2])[C](OC=O)C#N', '-470.03947']
# ['054078', '[O-]C(=O)C(NC=[NH2+])C#C', 'O=C=O.C(=[NH]C=[NH2])C#C', '-453.921192']
# ['054079', '[O-]C(=O)C(NC=[NH2+])C#N', 'O=C=O.C(=[NH]C=[NH2])C#N', '-470.030837']
# ['054102', 'CC1(C2C[NH+]1C2)C([O-])=O', 'C[C@]1([C@H]2C[N@@H]1C2)C(=O)[O]', '-439.005711']
# ['054119', 'CC1(C2C[NH2+]C12)C([O-])=O', 'C[C@]1([C@H]2C[NH2][C@@H]12)C(=O)[O]', '-439.017693']
# ['054124', 'NC1(C2C[NH2+]C12)C([O-])=O', 'N[C@]1([C@H]2C[NH2][C@@H]12)C(=O)[O]', '-455.080937']
# ['054126', 'OC1(C2C[NH2+]C12)C([O-])=O', 'O[C@]1([C@H]2C[NH2][C@@H]12)C(=O)[O]', '-474.966701']
# [10:33:50] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:50] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 7 N, 4, is greater than permitted
# ['054296', 'NC(=[NH2+])C1(CN1)C([O-])=O', '[NH2]=C(N)[C]1CN1.C(=O)=O', '-471.210889']
# ['054384', 'CC12CC(C1)([NH2+]2)C([O-])=O', 'C[C@@]12C[C@@](C1)([NH2]2)C(=O)[O]', '-439.028975']
# ['054400', '[O-]C(=O)C12CC([NH2+]1)C=C2', 'O=C([O])[C@@]12C[C@@H]([NH2]1)C=C2', '-437.838903']
# ['054409', '[O-]C(=O)C12CC(C1)C[NH2+]2', '[O]C(=O)[C@@]12C[C@@H](C1)C[NH2]2', '-439.065409']
# ['054410', '[O-]C(=O)C12CC(C1)[NH2+]C2', 'O=C([O])[C@@]12C[C@@H](C1)[NH2]C2', '-439.038329']
# ['054412', '[O-]C(=O)C12C[NH+](C1)CC2', 'O=C([O])[C@@]12C[N@@H](C1)CC2', '-439.03848']
# ['054422', 'CC12CC1(C[NH2+]2)C([O-])=O', 'C[C@]12C[C@]1(C[NH2]2)C(=O)[O]', '-439.031735']
# ['054538', '[O-]C(=O)C12CC1[NH2+]CC2', '[O]C(=O)[C@]12C[C@H]1[NH2]CC2', '-439.047551']
# ['054569', '[O-]C(=O)C12[NH2+]C3C1CC23', 'O=C([O])[C@@]12[NH2][C@H]3[C@@H]1C[C@@H]23', '-437.793304']
# ['054582', '[O-]C(=O)C12CC3[NH2+]C1C23', 'O=C([O])[C@@]12C[C@H]3[NH2][C@@H]1[C@@H]23', '-437.79076']
# ['054611', 'CC1=C(C[NH2+]C1)C([O-])=O', 'CC1=C(C[NH2]C1)C(=O)[O]', '-439.069339']
# ['054615', 'NC1=C(C[NH2+]C1)C([O-])=O', 'NC1=C(C[NH2]C1)C(=O)[O]', '-455.127295']
# ['054618', 'NC(=[NH2+])C1=CC(=O)[CH-]N1', 'NC(=[NH2])C1=CC(=O)[CH]N1', '-434.065807']
# ['054619', 'NC(=[NH2+])C1=CC(=O)N[CH-]1', 'NC(=[NH2])C1=CNC(=O)[CH]1', '-434.092954']
# ['054620', 'NC(=[NH2+])C1=CC(=O)O[CH-]1', 'NC(=[NH2])[C]([CH][C][O])C=O', '-453.976034']
# ['054629', '[O-]C(=O)C1=CC2CC1[NH2+]2', 'O=C([O])[C]1[CH][C@@H]2C[C@H]1[NH2]2', '-437.820896']
# ['054691', '[O-]C(=O)C1=CCC[NH2+]C1', '[O]C(=O)C1=CCC[NH2]C1', '-439.06337']
# ['054692', '[O-]C(=O)C1=CC[NH2+]CC1', '[O]C(=O)C1=CC[NH2]CC1', '-439.055918']
# ['054766', 'CC12C[NH+](C1)C2C([O-])=O', 'C[C@@]12C[N@@H](C1)[C@H]2C(=O)[O]', '-439.013163']
# ['054794', '[O-]C(=O)C1C2CC1[NH2+]C2', 'O=C([O])[C@H]1[C@H]2C[C@@H]1[NH2]C2', '-439.034641']
# ['054795', '[O-]C(=O)C1C2CCC1[NH2+]2', '[O]C(=O)[C@H]1[C@H]2CC[C@@H]1[NH2]2', '-439.046692']
# ['054796', '[O-]C(=O)C1C2C[NH+]1CC2', '[O]C(=O)[C@H]1[C@H]2C[N@@H]1CC2', '-439.058326']
# ['054885', 'NC(=[NH2+])[C-]1N=COC1=O', 'NC(=[NH2])[C]1N=COC1=O', '-470.081061']
# ['054899', 'NC(=[NH2+])[C-]1OC(=O)C=C1', 'NC(=[NH2])[C]1OC(=O)C=C1', '-454.004009']
# ['054900', 'NC(=[NH2+])N1[CH-]C(=O)C=C1', 'NC(=[NH2])N1[CH]C(=O)C=C1', '-434.060449']
# ['054994', '[O-]C(=O)C1CC11CC[NH2+]1', '[O]C(=O)[C@H]1C[C@]21CC[NH2]2', '-439.017339']
# ['055145', '[O-]C(=O)C1CC2C[NH+]1C2', '[O]C(=O)[C@H]1C[C@H]2C[N@@H]1C2', '-439.057642']
# ['055146', '[O-]C(=O)C1C[NH+]2CC1C2', '[O]C(=O)[C@H]1C[N@@H]2C[C@H]1C2', '-439.039805']
# ['055187', '[O-]C(=O)C1CC2CC[NH+]12', '[O]C(=O)[C@H]1C[C@H]2CC[N@@H]12', '-439.045616']
# ['055190', '[O-]C(=O)C1C[NH+]2CCC12', '[O]C(=O)[C@H]1C[N@H]2CC[C@@H]12', '-439.035457']
# ['055209', 'NC(=[NH2+])[C-]1NC=CC1=O', 'NC(=[NH2])[C]1NC=CC1=O', '-434.117539']
# ['055408', 'CC(=O)[C-]1C[NH2+]CC1=O', 'CC(=O)[C]1C[NH2]CC1=O', '-439.086725']
# ['055410', 'CC(=O)[C-]1[NH2+]CCC1=O', 'CC(=O)[C]1[NH2]CCC1=O', '-439.108603']
# ['055450', '[O-]C(=O)C1C[NH2+]CC=C1', '[O]C(=O)[C@H]1C[NH2]CC=C1', '-439.065732']
# ['055476', '[O-]C(=O)C1CCC[NH2+]C1', 'O=C([O])[C@H]1CCC[NH2]C1', '-440.269427']
# ['055477', '[O-]C(=O)C1CC[NH2+]CC1', '[O]C(=O)C1CC[NH2]CC1', '-440.26006']
# ['055479', '[O-]C(=O)C1C[NH2+]CCO1', '[O]C(=O)[C@H]1C[NH2]CCO1', '-476.177733']
# ['055484', 'NC(=[NH2+])C#CCC([O-])=O', 'NC(=[NH2])C#C[CH2].C(=O)=O', '-453.971495']
# ['055499', 'CC(=[NH2+])NC(=N)C([O-])=O', 'CC(=[NH2])NC(=N)C(=O)[O]', '-471.254799']
# ['055518', 'NC(=[NH2+])CC(=O)C([O-])=O', '[NH2]=C(N)[CH2].[C]=O.C(=O)=O', '-491.147261']
# ['055610', '[O-]C(=O)CC(=[NH2+])NC=N', 'O=C=O.[CH2]C(=[NH2])NC=N', '-471.265985']
# ['055611', 'CC(=[NH2+])N[C-](C#N)C#N', 'CC(=[NH2])[NH]=C(C#N)C#N', '-412.993011']
# ['055619', 'NC(=[NH2+])C[C-](C#N)C#N', '[NH2]=C(N)C[C](C#N)C#N', '-412.996653']
# ['055620', 'NC(=[NH2+])N[C-](C#N)C#N', 'NC(=[NH2])[NH]=C(C#N)C#N', '-429.054052']
# ['055621', 'NC(=[NH2+])O[C-](C#N)C#N', 'NC(=[NH2])O[C](C#N)C#N', '-448.918162']
# ['055701', 'NC1(CC([O-])=O)C[NH2+]C1', 'NC1(CC(=O)[O])C[NH2]C1', '-456.294492']
# ['055703', 'OC1(CC([O-])=O)C[NH2+]C1', '[O]C1(CC(=O)O)C[NH2]C1', '-476.190432']
# [10:33:51] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 4 N, 4, is greater than permitted
# ['055944', '[O-]C(=O)CC1CC2[NH2+]C12', '[O]C(=O)C[C@H]1C[C@H]2[NH2][C@@H]12', '-438.998187']
# ['056055', '[O-]C(=O)C[NH+]=CN1CC1', 'O=C=O.C=[NH][CH]N1CC1', '-455.111004']
# ['056072', '[O-]C(=O)CN=CNC=[NH2+]', 'O=C=O.[CH2]N=CNC=[NH2]', '-471.200679']
# ['056238', 'NC(=[NH2+])CNCC([O-])=O', 'NC(=[NH2])C=[NH]CC(=O)O', '-472.417424']
# ['056343', '[O-]C(=O)CCCNC=[NH2+]', '[O]C(=O)CCCNC=[NH2]', '-456.305265']
# ['057172', 'NC(=[NH2+])[C-](O)C(=O)C#N', 'NC(=[NH2])[C](O)C(=O)C#N', '-470.041313']
# ['057181', 'NC(=[NH2+])[C-](O)C(=O)C=O', 'NC(=[NH2])[C](O)C(=O)C=O', '-491.121141']
# ['057736', 'CC(N)=[NH+][C-](C#N)C#N', 'CC(=[NH2])[NH]=C(C#N)C#N', '-412.993012']
# ['057737', 'NC(N)=[NH+][C-](C#C)C#N', 'NC(=[NH2])[NH]=C(C#C)C#N', '-412.942185']
# ['057945', 'CN(C)C(=[NH2+])CC([O-])=O', 'CN(C)C(=[NH2])[CH2].C(=O)=O', '-456.391606']
# [10:33:51] Explicit valence for atom # 6 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:51] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 7 N, 4, is greater than permitted
# [10:33:52] Explicit valence for atom # 8 N, 4, is greater than permitted
# ['058281', 'CC(CC([O-])=O)[NH+](C)C', 'C[C@@H](CC(=O)[O])[NH](C)C', '-441.446778']
# ['058614', 'CC([NH3+])C1(CO1)C([O-])=O', 'C[C@@H]([NH3])[C@]1(CO1)C(=O)[O]', '-476.169378']
# ['058982', 'C[NH+](C)C1=CC(=O)O[CH-]1', 'C[NH](C)C1=COC(=O)[CH]1', '-439.040257']
# ['059827', 'C[NH+](C)CC#CC([O-])=O', 'C[NH](C)C[C][C]C(=O)[O]', '-438.981629']
# ['059849', 'CC(C)NC(=[NH2+])C([O-])=O', 'CC(C)NC(=[NH2])C(=O)[O]', '-456.399811']
# ['059966', 'CC(C[NH+](C)C)C([O-])=O', 'C[C@@H](C[NH](C)C)C(=O)[O]', '-441.448746']
# ['059977', 'C[NH+](C)CC(O)C([O-])=O', 'C[NH](C)C[C@@H](O)C(=O)[O]', '-477.412763']
# ['060660', 'OC(C1C[NH2+]C1)C([O-])=O', 'O[C@@H](C1C[NH2]C1)C(=O)[O]', '-476.176938']
# ['060718', 'CN(C=[NH2+])C(=N)C([O-])=O', 'CN(C=[NH2])C(=N)C(=O)[O]', '-471.210465']
# ['060780', 'CN(C=[NH2+])[C-](C#N)C#N', 'CN(C=[NH2])[C](C#N)C#N', '-412.978993']
# ['061435', 'NC(=[NH2+])CC(O)C([O-])=O', 'NC(=[NH2])C[C@@H](O)C(=O)[O]', '-492.30444']
# ['061440', 'NC(CC([O-])=O)C(N)=[NH2+]', 'N[C@@H](CC(=O)[O])C(=[NH2])N', '-472.41025']
# ['061451', 'CC(CC([O-])=O)C1C[NH2+]1', 'C[C@@H](CC(=O)[O])[C@H]1C[NH2]1', '-440.214131']
# [10:33:55] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:55] Explicit valence for atom # 0 N, 4, is greater than permitted
# ['074137', '[NH3+]C1=CC(=O)NC(=O)[CH-]1', '[NH3]C1=CC(=O)NC(=O)[CH]1', '-453.968011']
# ['074176', '[NH3+]C1=CC(=O)O[C-]1C=O', '[NH3]C1=C(OC(=O)[CH]1)C=O', '-473.805098']
# [10:33:56] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 8 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:56] Explicit valence for atom # 0 N, 4, is greater than permitted
# ['076135', 'CC1([NH3+])C(N)C1C([O-])=O', 'C[C@@]1([NH3])[C@@H](N)[C@H]1C(=O)[O]', '-456.286637']
# ['076136', 'CC1([NH3+])C(O)C1C([O-])=O', 'C[C@@]1([NH3])[C@@H](O)[C@H]1C(=O)[O]', '-476.177957']
# ['076143', 'CC1C(C([O-])=O)C1(C)[NH3+]', 'C[C@H]1[C@@H](C(=O)[O])[C@]1(C)[NH3]', '-440.237448']
# ['076372', 'CC1(C(N)C1[NH3+])C([O-])=O', 'C[C@]1([C@@H](N)[C@H]1[NH3])C(=O)[O]', '-456.297347']
# ['076373', 'CC1(C([NH3+])C1O)C([O-])=O', 'C[C@]1([C@@H]([NH3])[C@H]1O)C(=O)[O]', '-476.169941']
# ['076380', 'CC1C([NH3+])C1(C)C([O-])=O', 'C[C@H]1[C@@H]([NH3])[C@]1(C)C(=O)[O]', '-440.234295']
# ['076394', 'NC1C([NH3+])C1(N)C([O-])=O', 'N[C@H]1[C@@H]([NH3])[C@]1(N)C(=O)[O]', '-472.362553']
# ['076395', 'NC1C([NH3+])C1(O)C([O-])=O', 'N[C@H]1[C@@H]([NH3])[C@]1(O)C(=O)[O]', '-492.248184']
# ['076397', '[NH3+]C1C(O)C1(O)C([O-])=O', '[NH3][C@H]1[C@@H](O)[C@]1(O)C(=O)[O]', '-512.122082']
# [10:33:57] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:57] Explicit valence for atom # 3 N, 4, is greater than permitted
# ['080595', '[NH3+]C1C2CC(C12)C([O-])=O', '[NH3][C@H]1[C@H]2C[C@@H]([C@@H]12)C(=O)[O]', '-438.997483']
# ['080597', '[NH3+]C1C2OC(C12)C([O-])=O', '[NH3][C@H]1[C@H]2O[C@@H]([C@@H]12)C(=O)[O]', '-474.919168']
# ['081049', 'CC1C2CC1([NH2+]2)C([O-])=O', 'C[C@H]1[C@H]2C[C@@]1([NH2]2)C(=O)[O]', '-439.020617']
# ['081054', 'CC1[NH+]2CC1(C2)C([O-])=O', 'C[C@H]1[N@H]2C[C@@]1(C2)C(=O)[O]', '-438.995664']
# ['081057', 'C[NH+]1C2CC1(C2)C([O-])=O', 'C[NH]1[C@H]2C[C@@]1(C2)C(=O)[O]', '-439.017318']
# ['081567', 'CC1C2C[NH+]1C2C([O-])=O', 'C[C@H]1[C@H]2C[N@@H]1[C@H]2C(=O)[O]', '-439.005365']
# ['081568', 'CC1C2[NH2+]C1C2C([O-])=O', 'C[C@H]1[C@H]2[NH2][C@@H]1[C@H]2C(=O)[O]', '-438.999252']
# ['081573', 'C[NH+]1C2CC1C2C([O-])=O', 'C[NH]1[C@H]2C[C@@H]1[C@H]2C(=O)[O]', '-438.99721']
# ['081578', '[NH3+]C1C2CC1C2C([O-])=O', '[NH3][C@H]1[C@H]2C[C@@H]1[C@H]2C(=O)[O]', '-438.980256']
# ['081579', '[NH3+]C1C2NC1C2C([O-])=O', '[NH3][C@H]1[C@H]2N[C@@H]1[C@H]2C(=O)[O]', '-455.03127']
# ['081580', '[NH3+]C1C2OC1C2C([O-])=O', '[NH3][C@H]1[C@H]2O[C@@H]1[C@H]2C(=O)[O]', '-474.903473']
# ['081581', 'OC1C2[NH2+]C1C2C([O-])=O', 'O[C@H]1[C@H]2[NH2][C@@H]1[C@H]2C(=O)[O]', '-474.930942']
# [10:33:58] Explicit valence for atom # 1 N, 4, is greater than permitted
# [10:33:58] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:58] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:58] Explicit valence for atom # 3 N, 4, is greater than permitted
# [10:33:58] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:33:58] Explicit valence for atom # 3 N, 4, is greater than permitted
# ...
# [10:34:09] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:09] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:09] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:09] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 2 4 6 7 8
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 7
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 2 3 5 7 8
# [10:34:09] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:34:09] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:10] Explicit valence for atom # 0 N, 4, is greater than permitted
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4
# [10:34:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:34:10] Explicit valence for atom # 4 N, 4, is greater than permitted
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 5 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 5 7 8
# ['129023', 'N=C1C=C(NN=N1)C#C', '[NH]c1cc([nH]nn1)C#C', '-411.727865']
# ['129027', 'N=C1C=C2CCN2N=N1', '[NH]c1cc2CCn2nn1', '-412.941444']
# ['129036', 'N=C1C=CN(C=O)N=N1', '[NH]c1ccn(C=O)nn1', '-448.908481']
# ['129037', 'N=C1C=CN=NN1C=O', '[NH]c1ccnnn1C=O', '-448.909509']
# ['129056', 'N=C1C=NC=NN1C=O', '[NH]c1cncnn1C=O', '-448.934689']
# ['129060', 'N=C1C=NN(C=O)N=C1', '[NH]c1cnn(C=O)nc1', '-448.916513']
# ['129061', 'N=C1C=NN(C=O)N=N1', '[NH]c1cnn(C=O)nn1', '-464.937633']
# ['129063', 'N=C1C=NN2CCC2=N1', '[NH]c1cnn2CCc2n1', '-412.973447']
# ['129069', 'N=C1C=NNC(=O)N=C1', '[NH]c1cn[nH]c(=O)nc1', '-448.92212']
# ['129071', 'N=C1C=NNC=C1C#C', '[NH]c1cn[nH]cc1C#C', '-395.702435']
# ['129074', 'N=C1C=NNC=CC1=O', '[NH]c1cn[nH]ccc1=O', '-432.859358']
# ['129076', 'N=C1C=NNN=C1C#C', '[NH]c1cn[nH]nc1C#C', '-411.729079']
# ['129100', 'N=C1C=NON=NC1=O', '[NH]c1cnoc1=O.N#N', '-484.878482']
# ['129123', 'N=C1N=CC=NN1C=O', '[NH]c1nccnn1C=O', '-448.938032']
# ['129127', 'N=C1N=CN=NN1C=O', '[NH]c1ncnnn1C=O', '-464.961718']
# ['129141', 'N=C1N=NNC=C1C#C', '[NH]c1nn[nH]cc1C#C', '-411.727444']
# ['129143', 'N=C1N=NNN=C1C#C', '[NH]c1nn[nH]nc1C#C', '-427.753914']
# ['129183', '[NH2+]=C1NCC2=C1[N-]N=N2', 'N[C]1NCc2c1nnn2', '-429.038603']
# ['129188', 'N=C1NN=C(C=N1)C#C', '[NH]c1[nH]nc(cn1)C#C', '-411.759084']
# ['129189', 'N=C1NN=C(C=N1)C#N', '[NH]c1[nH]nc(cn1)C#N', '-427.860498']
# ['129192', 'N=C1NN=C(N=C1)C#C', '[NH]c1[nH]nc(nc1)C#C', '-411.751462']
# ['129193', 'N=C1NN=C(N=C1)C#N', '[NH]c1[nH]nc(nc1)C#N', '-427.853149']
# ['129201', 'N=C1NN=CC(=N1)C#N', '[NH]c1[nH]ncc(n1)C#N', '-427.857058']
# ['129205', 'N=C1NN=CC(C=O)=N1', '[NH]c1[nH]ncc(C=O)n1', '-448.928173']
# ['129214', 'N=C1NN=CN=C1C#C', '[NH]c1[nH]ncnc1C#C', '-411.752012']
# ['129215', 'N=C1NN=CN=C1C#N', '[NH]c1[nH]ncnc1C#N', '-427.851527']
# ['129216', 'N=C1NN=CN=C1C=O', '[NH]c1[nH]ncnc1C=O', '-448.924818']
# ['129219', 'N=C1NN=NC(=C1)C#C', '[NH]c1[nH]nnc(c1)C#C', '-411.73103']
# ['129220', 'N=C1NN=NC(=C1)C#N', '[NH]c1[nH]nnc(c1)C#N', '-427.831432']
# ['129224', 'N=C1NN=NC(=N1)C#C', '[NH]c1[nH]nnc(n1)C#C', '-427.784343']
# ['129225', 'N=C1NN=NC(=N1)C#N', '[NH]c1[nH]nnc(n1)C#N', '-443.881608']
# ['129229', 'N=C1NN=NC(C=O)=C1', '[NH]c1[nH]nnc(C=O)c1', '-448.90588']
# ['129230', 'N=C1NN=NC(C=O)=N1', '[NH]c1[nH]nnc(C=O)n1', '-464.957511']
# ['129231', 'N=C1NN=NC=C1C#C', '[NH]c1[nH]nncc1C#C', '-411.731796']
# ['129232', 'N=C1NN=NC=C1C#N', '[NH]c1[nH]nncc1C#N', '-427.832616']
# ['129233', 'N=C1NN=NC=C1C=O', '[NH]c1[nH]nncc1C=O', '-448.909122']
# ['129317', 'N=C1ON=NC(=O)N=C1', '[NH]c1oc(=O)nc1.N#N', '-484.942758']
# ['129336', 'N=C1[N-]N=C(NC=[NH2+])O1', '[NH]c1nnc(NC=[NH2])o1', '-466.135691']
# ['129337', 'N=C1[N-]C(NC=[NH2+])=NO1', '[NH]c1nc(NC=[NH2])no1', '-466.13463']
# ['129340', '[NH2+]=CNCC1=N[N-]N=N1', '[NH2]=CNCc1nnnn1', '-446.256138']
# ['129372', 'NC(=[NH2+])C1=C([O-])C=NN1', '[NH2]=C(N)[C]1C(=O)C=NN1', '-450.151498']
# ['129373', 'NC(=[NH2+])C1=C(O)N=N[N-]1', '[NH2]=C(N)c1c(O)nnn1', '-466.193449']
# ['129374', 'NC(=[NH2+])C1=C([O-])ON=C1', 'NC(=[NH2])[C]1C(=O)ON=C1', '-470.038212']
# ['129383', 'NC(=[NH2+])C1=NC(O)=N[N-]1', 'NC(=[NH2])c1nc(O)nn1', '-466.219405']
# ['129387', 'NC(=[NH2+])C1=N[N-]C(=N)O1', 'NC(=[NH2])c1nnc([NH])o1', '-466.188483']
# ['129393', 'NC(=[NH2+])C1=NOC(=N)[N-]1', 'NC(=[NH2])c1noc([NH])n1', '-466.165311']
# ['129401', 'NC(=[NH2+])N1C=C([O-])C=N1', 'NC(=[NH2])N1[CH]C(=O)C=N1', '-450.113355']
# ['129406', 'NC(=[NH2+])N1N=NC=C1[O-]', 'NC(=[NH2])n1nncc1=O', '-466.197723']
# ['129410', 'NC(=[NH2+])NC1=CN=N[N-]1', 'NC(=[NH2])Nc1cnnn1', '-446.296056']
# ['129412', 'NC(=[NH2+])NC1=NC=N[N-]1', '[NH2]=C(N)Nc1ncnn1', '-446.328308']
# ['129578', 'NC(N)=[NH+]C1=CN=N[N-]1', '[NH2]=C(N)Nc1cnnn1', '-446.296056']
# ['129579', 'NC(N)=[NH+]C1=NC=N[N-]1', '[NH2]=C(N)Nc1ncnn1', '-446.328309']
# ['129581', 'NC(N)=[NH+]C1=N[N-]N=N1', 'NC(=[NH2])Nc1nnnn1', '-462.350448']
# ['129642', 'NC1=C(N)C(=N)N=NN1', 'Nc1c(N)c([NH])nn[nH]1', '-446.282165']
# ['129644', 'NC1=C(N)C(=N)NN=N1', 'Nc1c(N)c([NH])[nH]nn1', '-446.297558']
# ['129702', 'NC1=C(O)C(=N)N=NN1', 'Nc1c(O)c([NH])nn[nH]1', '-466.165138']
# ['129704', 'NC1=C(O)C(=N)NN=N1', 'Nc1c(O)c([NH])[nH]nn1', '-466.177184']
# ['129723', 'NC1=C(O)N=NNC1=N', 'Nc1c(O)nn[nH]c1[NH]', '-466.178105']
# ['129733', 'NC1=C(O)NN=NC1=N', 'Nc1c(O)[nH]nnc1[NH]', '-466.161693']
# ['129994', 'NC1=[NH+]C2=C(C1)C=N[N-]2', 'N[C]1Nc2c(C1)cnn2', '-412.966331']
# ['129996', 'NC1=[NH+]C2=C(C1)N=N[N-]2', 'N[C]1Nc2c(C1)nnn2', '-429.007171']
# ['130139', 'NC1=NNC(=O)NC1=N', 'Nc1n[nH]c(=O)[nH]c1[NH]', '-466.236846']
# ['130182', 'NC1=NNC2=C1N=NO2', 'Nc1n[nH]c(=O)c1[N][N]', '-464.985937']
# ['130211', 'NC1=NNN=C(N)C1=N', 'Nc1n[nH]nc(N)c1[NH]', '-446.300727']
# ['130336', '[NH3+][C-]1C=CC2=C1N=NO2', '[NH3]c1ccc2c1nno2', '-432.779522']
# ['130337', '[NH3+][C-]1C=CC2=C1NN=N2', '[NH3][C@@H]1C=Cc2c1[nH]nn2', '-412.908261']
# ['130338', '[NH3+][C-]1C=CC2=C1ON=N2', '[NH3]C1=CC=C(C1=O)[N][N]', '-432.819105']
# ['130339', '[NH3+][C-]1C=CC2=NON=C12', '[NH3]c1ccc2nonc12', '-432.757427']
# ['130345', '[NH3+]C1COC2=C1N=N[N-]2', 'N.[CH]1COc2c1nnn2', '-450.070438']
# ['130355', 'NC=[NH+]C1=C([O-])C=NN1', '[NH2]=CN[C]1C(=O)C=NN1', '-450.095625']
# ['130356', 'NC=[NH+]C1=C(O)N=N[N-]1', '[NH2]=CNc1c(O)nnn1', '-466.146313']
# ['130357', 'NC=[NH+]C1=C([O-])ON=C1', '[NH2]=CN[C]1C(=O)ON=C1', '-469.983461']
# ['130358', 'NC=[NH+]C1=C([O-])ON=N1', '[NH2]=CNc1c(=O)onn1', '-486.031']
# ['130366', 'NC=[NH+]C1=NC(O)=N[N-]1', '[NH2]=CNc1nc(O)nn1', '-466.176292']
# ['130370', 'NC=[NH+]C1=N[N-]C(=N)O1', '[NH2]=CNc1nnc([NH])o1', '-466.135688']
# ['130374', 'NC=[NH+]C1=NNC=C1[O-]', '[NH2]=CNC1=NN[CH]C1=O', '-450.102532']
# ['130377', 'NC=[NH+]C1=NOC(=N)[N-]1', '[NH2]=CNc1noc([NH])n1', '-466.13463']
# ['130382', 'NC=[NH+]C1=NOC([O-])=C1', '[NH2]=CNC1=NOC(=O)[CH]1', '-469.969341']
# ['130383', 'NC=[NH+]C1=NOC=C1[O-]', '[NH2]=CNC1=NO[CH]C1=O', '-469.951243']
# ['130385', 'NC=[NH+]CC1=N[N-]N=N1', '[NH2]=CNCc1nnnn1', '-446.256136']
# ['130386', '[NH3+]CC#CC1=CN=N[N-]1', 'N.[CH2]C#Cc1cnnn1', '-412.900736']
# ['130387', '[NH3+]CC#CC1=NC=N[N-]1', 'N.[CH2]C#Cc1ncnn1', '-412.919665']
# ['130388', 'NC(C[NH3+])C1=N[N-]N=N1', '[NH3][C@@H](CN)c1nnnn1', '-447.442444']
# ['130393', '[NH3+]CC1=C(CO)N=N[N-]1', '[NH3]Cc1c(CO)nnn1', '-451.266582']
# ['130415', '[NH3+]CC1=NC(=N)N=N[N-]1', 'NCc1[nH]c([NH])nnn1', '-446.275011']
# ['130417', 'NCC1=NC(=N)NN=N1', 'NCc1nc([NH])[nH]nn1', '-446.271675']
# ['130427', 'NCC1=NC=NNC1=N', 'NCc1ncn[nH]c1[NH]', '-430.245451']
# ['130431', 'NCC1=NNC(=N)C=N1', 'NCc1n[nH]c([NH])cn1', '-430.243476']
# ['130438', '[NH3+]CC1=N[N-]N=CC1=N', 'NCc1[nH]nncc1[NH]', '-430.206684']
# ['130453', '[NH3+]CCC1=NOC(=N)[N-]1', '[NH3]CCc1noc([NH])n1', '-451.222784']
# ['130454', '[NH3+]CCC1=NOC([O-])=C1', '[NH3]CCC1=NOC(=O)[CH]1', '-455.057774']
# ['130466', 'O1C=C2C=CN=C2C=N1', 'O1[CH]c2ccnc2C=N1', '-415.608408']
# ['130467', 'O1C=C2C=CN=C2N=N1', 'O=Cc1ccnc1[N][N]', '-431.678549']
# ['130469', 'O1C=C2C=NC=C2C=N1', 'O1[CH]c2cncc2C=N1', '-415.602059']
# ['130470', 'O1C=C2C=NC=C2N=N1', 'O=Cc1cncc1[N][N]', '-431.677395']
# ['130475', 'O1C=C2N=CC=C2C=N1', 'O1[CH]c2nccc2C=N1', '-415.609985']
# ['130476', 'O1C=C2N=CC=C2N=N1', 'O=Cc1nccc1[N][N]', '-431.677836']
# ['130479', 'O1C=C2N=CN=C2C=N1', 'O1[CH]c2ncnc2C=N1', '-431.666044']
# ['130480', 'O1C=C2N=CN=C2N=N1', 'O=Cc1ncnc1[N][N]', '-447.733869']
# ['130512', 'O1N=CC=C2C=CN=C12', 'O1N=C[CH]c2ccnc12', '-415.605846']
# ['130513', 'O1N=CC=C2C=NC=C12', 'O1N=C[CH]c2cncc12', '-415.586666']
# ['130514', 'O1N=CC=C2N=CC=C12', 'O1N=C[CH]c2nccc12', '-415.604051']
# ['130515', 'O1N=CC=C2N=CN=C12', 'O1N=C[CH]c2ncnc12', '-431.666488']
# ['130531', 'O1N=NC2=CN=CC2=N1', '[O][N]c1c(N=[N])cnc1', '-447.635834']
# ['130667', 'O=C1N=NOC=C1C#N', 'c1(ccnnc1=O)C#N', '-430.395031']
# ['131165', '[O-]C1=C(NC=[NH2+])NN=C1', 'O=C1[C](NC=[NH2])NN=C1', '-450.095624']
# ['131200', '[O-]C1=C2C[NH2+]CC2=NO1', 'O=C1[C]2C[NH2]CC2=NO1', '-453.885937']
# ['131350', 'OC1=NNC(=O)NC1=N', 'Oc1n[nH]c(=O)[nH]c1[NH]', '-486.113597']
# ['131648', 'OCC1=CC(=N)N=NN1', 'OCc1cc([NH])nn[nH]1', '-450.094172']
# ['131651', 'OCC1=CC(=N)NN=N1', 'OCc1cc([NH])[nH]nn1', '-450.097972']
# ['131677', 'OCC1=CN=NNC1=N', 'OCc1cnn[nH]c1[NH]', '-450.098029']
# ['131686', 'OCC1=CNN=NC1=N', 'OCc1c[nH]nnc1[NH]', '-450.094596']
# ['131697', 'OCC1=NC(=N)NN=C1', 'OCc1nc([NH])[nH]nc1', '-450.111749']
# ['131698', 'OCC1=NC(=N)NN=N1', 'OCc1nc([NH])[nH]nn1', '-466.151378']
# ['131714', 'OCC1=NC=NNC1=N', 'OCc1ncn[nH]c1[NH]', '-450.125934']
# ['131729', 'OCC1=NNC(=N)C=N1', 'OCc1n[nH]c([NH])cn1', '-450.12155']
# ['131730', 'OCC1=NNC(=N)N=C1', 'OCc1n[nH]c([NH])nc1', '-450.117009']
# ['132096', 'CC1=C(F)NC(=N)C=N1', 'Cc1c(F)[nH]c([NH])cn1', '-458.128493']
# ['132116', 'NC1=C(F)NC(=N)C=N1', 'Nc1c(F)[nH]c([NH])cn1', '-474.173475']
# ['132138', 'FC1=C(F)N=CC(=N)N1', 'Fc1c(F)ncc([NH])[nH]1', '-518.071091']
# ['132343', 'OC1=NC(F)=NC(=O)O1', 'OC(=O)[N]C(=[N]=C=O)F', '-549.926388']
# ['132344', 'OC1=NC(=O)OC(F)=N1', 'OC(=[N]=C=O)[N]C(=O)F', '-549.927723']
# ['132345', 'FC1=NC(F)=NC(=O)O1', 'FC(=O)[N]C(=[N]=C=O)F', '-573.94274']
# ['132438', 'CC1=NC=C(F)NC1=N', 'Cc1ncc(F)[nH]c1[NH]', '-458.127722']
# ['132956', 'CN1C(=N)C=NC=C1F', 'Cn1c([NH])cncc1F', '-458.118799']
# ['133007', 'CN=C1NC(F)=CN=C1', 'C[N]c1[nH]c(F)cnc1', '-458.11307']
# ['133136', 'CC1=C(F)C(=N)N=NN1', 'Cc1c(F)c([NH])nn[nH]1', '-474.124801']
# ['133139', 'CC1=C(F)C(=N)NN=N1', 'Cc1c(F)c([NH])[nH]nn1', '-474.131326']
# ['133159', 'CC1=C(F)N=NNC1=N', 'Cc1c(F)nn[nH]c1[NH]', '-474.139031']
# ['133164', 'CC1=C(F)NN=NC1=N', 'Cc1c(F)[nH]nnc1[NH]', '-474.129359']
# ['133189', 'CC1=NC(F)=NNC1=N', 'Cc1nc(F)n[nH]c1[NH]', '-474.164708']
# ['133196', 'CC1=NNC(=N)N=C1F', 'Cc1n[nH]c([NH])nc1F', '-474.173509']
# ['133202', 'CC1=NNC(F)=NC1=N', 'Cc1n[nH]c(F)nc1[NH]', '-474.174244']
# ['133223', 'CN1C=C(F)C(=N)N=N1', 'Cn1cc(F)c([NH])nn1', '-474.114227']
# ['133234', 'CN1N=C(F)N=CC1=N', 'Cn1nc(F)ncc1[NH]', '-474.15261']
# ['133236', 'CN1N=CC(=N)C(F)=N1', 'Cn1ncc([NH])c(F)n1', '-474.129514']
# ['133238', 'CN1N=CC(=N)N=C1F', 'Cn1ncc([NH])nc1F', '-474.161646']
# ['133244', 'CN1N=CC(F)=NC1=N', 'Cn1ncc(F)nc1[NH]', '-474.16399']
# ['133250', 'CN1N=NC(=N)C(F)=N1', 'Cn1nnc([NH])c(F)n1', '-490.153541']
# ['133251', 'CN1N=NC(=N)C=C1F', 'Cn1nnc([NH])cc1F', '-474.120447']
# ['133252', 'CN1N=NC(=N)N=C1F', 'Cn1nnc([NH])nc1F', '-490.182275']
# ['133256', 'CN1N=NC(F)=CC1=N', 'Cn1nnc(F)cc1[NH]', '-474.133054']
# ['133258', 'CN1N=NC(F)=NC1=N', 'Cn1nnc(F)nc1[NH]', '-490.19362']
# ['133260', 'CN1N=NC=C(F)C1=N', 'Cn1nncc(F)c1[NH]', '-474.126834']
# ['133262', 'CN=C1C=C(F)NN=N1', 'C[N]c1cc(F)[nH]nn1', '-474.113783']
# ['133279', 'CN=C1NN=C(F)N=C1', 'C[N]c1[nH]nc(F)nc1', '-474.146705']
# ['133281', 'CN=C1NN=CC(F)=N1', 'C[N]c1[nH]ncc(F)n1', '-474.157506']
# ['133284', 'CN=C1NN=NC(F)=C1', 'C[N]c1[nH]nnc(F)c1', '-474.123416']
# ['133285', 'CN=C1NN=NC(F)=N1', 'C[N]c1[nH]nnc(F)n1', '-490.185821']
# ['133304', 'NC1=C(F)C(=N)N=NN1', 'Nc1c(F)c([NH])nn[nH]1', '-490.172541']
# ['133307', 'NC1=C(F)C(=N)NN=N1', 'Nc1c(F)c([NH])[nH]nn1', '-490.185513']
# ['133329', 'NC1=C(F)N=NNC1=N', 'Nc1c(F)nn[nH]c1[NH]', '-490.19566']
# ['133333', 'NC1=C(F)NN=CC1=N', 'Nc1c(F)[nH]ncc1[NH]', '-474.153437']
# ['133334', 'NC1=C(F)NN=NC1=N', 'Nc1c(F)[nH]nnc1[NH]', '-490.179842']
# ['133360', 'NC1=NC(F)=NNC1=N', 'Nc1nc(F)n[nH]c1[NH]', '-490.236885']
# ['133378', 'NC1=NNN=C(F)C1=N', 'Nc1n[nH]nc(F)c1[NH]', '-490.200021']
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 5 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 5 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 6
# [10:34:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:34:10] Explicit valence for atom # 2 N, 4, is greater than permitted
# [10:34:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 6 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 5 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 5 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 2 4 5 6 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 7 8
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 5 6 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 7
# [10:34:10] Can't kekulize mol.  Unkekulized atoms: 1 2 4 5 7

# %%
# Only keep the conformer with the lowest energy
for smi in tqdm(qm9_dict):
    mol_info = min(qm9_dict[smi], key=lambda k: k['energy'])
    qm9_dict[smi] = mol_info
len(qm9_dict)
# Out:
#   0%|          | 0/130132 [00:00<?, ?it/s]
# 130132

# %% [markdown]
# ## 3. Remove molecules that failed graph isomorphism check between SMILES from GDB17 and SMILES provided by the original QM9 paper after DFT optimization.

# %%
# Finding molelcules having different connectivity after B3LYP optimization in the original QM9 paper
connect = list()
for gdb_smi in tqdm(qm9_dict):
    n1 = read_smiles(gdb_smi)
    nonstereo_smi = re.sub(r'\\|\/|\@','', qm9_dict[gdb_smi]['parsed_smi'])
    n2 = read_smiles(nonstereo_smi)
    if (not nx.is_isomorphic(n1,n2)):
        connect.append(gdb_smi)
connect
# Out:
#   0%|          | 0/130132 [00:00<?, ?it/s]
# ['CC1C2C3C4=CCC13C42', 'CN1C2C3C4=CCC31C42']

# %%
# Remove gdb_smi from qm9_dict
for smi in connect:
    qm9_dict.pop(smi, None)
len(qm9_dict)
# Out:
# 130130

# %% [markdown]
# ## 4. Remove molecules having atomization energy per bond smaller than 100 kcal/mol using atomic and molecular energies provided by the original QM9 paper.

# %%
# Build a atom energy dictionary
with open('atomref.txt','r') as f:
    atom_dict = {'H':1,'C':6,'N':7,'O':8,'F':9}
    atomref = {}
    for i in range(5):
        next(f)
    for i in range(5):
        line = f.readline().rstrip().split()
        atom_num = atom_dict[line[0]]
        atomref[atom_num] = float(line[2])
atomref
# Out:
# {1: -0.500273, 6: -37.846772, 7: -54.583861, 8: -75.064579, 9: -99.71873}

# %%
# Get atomization energy and atomization energy per bond in kcal/mol
def getAtomizationEnergy(smiles, energy, atomref):
    mol = Chem.MolFromSmiles(smiles)
    mol = Chem.AddHs(mol)
    atom_energy_list = [atomref[atom.GetAtomicNum()] for atom in mol.GetAtoms()]
    ae = (sum(atom_energy_list) - energy) * 627.5 # Hartree to kcal/mol
    num_of_bonds = len(mol.GetBonds()) 
    ae_per_bond = ae / num_of_bonds
    
    return ae, ae_per_bond

# %%
# Add AE per bond into qm9_dict
for gdb_smi in tqdm(qm9_dict):
    ae, ae_per_bond = getAtomizationEnergy(qm9_dict[gdb_smi]['parsed_smi']\
                                       , qm9_dict[gdb_smi]['energy'], atomref)
    qm9_dict[gdb_smi]['AE'] = ae
    qm9_dict[gdb_smi]['AE_per_bond'] = ae_per_bond
# Out:
#   0%|          | 0/130130 [00:00<?, ?it/s]

# %%
# Get molecules with AE per bond < 100 kcal/mol
low_ae_mol = [(gdb_smi,qm9_dict[gdb_smi]['AE_per_bond']) for gdb_smi in qm9_dict if qm9_dict[gdb_smi]['AE_per_bond'] < 100]
len(low_ae_mol)
# Out:
# 104964

# %%
# Remove low AE per bond molecules from qm9_dict
for mol in low_ae_mol:
    qm9_dict.pop(mol[0], None)
len(qm9_dict)
# Out:
# 25166

# %% [markdown]
# ## 5. Retain molecules with at least one ring.

# %%
# Find molecules in qm9_dict that don't have ring structure
no_ring = list()
for gdb_smi in tqdm(qm9_dict):
    mol = Chem.MolFromSmiles(gdb_smi)
    if Chem.GetSSSR(mol) == 0:
        no_ring.append(gdb_smi)
no_ring
# Out:
#   0%|          | 0/25166 [00:00<?, ?it/s]
# ['O',
#  'C#C',
#  'C#N',
#  'C=O',
#  'C#CC',
#  'CC#N',
#  'CC=O',
#  'NC=O',
#  'CC(C)=O',
#  'CC(N)=O',
#  'NC(N)=O',
#  'C#CC#C',
#  'C#CC#N',
#  'N#CC#N',
#  'C#CC=O',
#  'N#CC=O',
#  'O=CC=O',
#  'CC#CC',
#  'C#CCC',
#  'CCC#N',
#  'N#CCN',
#  'C#CCO',
#  'N#CCO',
#  'CCC=O',
#  'CNC=O',
#  'COC=O',
#  'O=CCO',
#  'C#CC(C)=O',
#  'CC(=O)C#N',
#  'C#CC(N)=O',
#  'CC(=O)C=O',
#  'NC(=O)C=O',
#  'C#CC(C)C',
#  'CC(C)C#N',
#  'CC(N)C#N',
#  'C#CC(C)O',
#  'CC(O)C#N',
#  'CC(O)C=O',
#  'CC(=O)CO',
#  'CCC(C)=O',
#  'CCC(N)=O',
#  'COC(C)=O',
#  'COC(N)=O',
#  'NC(=O)CO',
#  'C#CCC#C',
#  'C#CCC#N',
#  'N#CCC#N',
#  'C#CCC=O',
#  'N#CCC=O',
#  'N=CNC=O',
#  'N=COC=O',
#  'O=CNC=O',
#  'C#CC#CC',
#  'CC#CC#N',
#  'CC#CC=O',
#  'CC#CCO',
#  'CC#CCC',
#  'C#CCCC',
#  'CCCC#N',
#  'CNCC#N',
#  'C#CCOC',
#  'COCC#N',
#  'C#CCCO',
#  'N#CCCO',
#  'CCOC=O',
#  'COCC=O',
#  'O=CCCO',
#  'C#CC(C)=NO',
#  'FC(F)(F)F',
#  'C#CC(C)(C)C',
#  'CC(C)(C)C#N',
#  'CC(C)(N)C#N',
#  'C#CC(C)(C)O',
#  'CC(C)(O)C#N',
#  'CC#CC(C)=O',
#  'CC#CC(N)=O',
#  'CC#CC(C)C',
#  'CC#CC(C)O',
#  'C#CCC(C)=O',
#  'CC(=O)CC#N',
#  'C#CCC(N)=O',
#  'N#CCC(N)=O',
#  'CC(=N)NC=O',
#  'CC(=N)OC=O',
#  'CC(=O)CC=O',
#  'CC(=O)NC=N',
#  'CC(=O)NC=O',
#  'CC(=O)OC=N',
#  'NC(=O)CC=O',
#  'N=CNC(N)=O',
#  'NC(=O)NC=O',
#  'N=COC(N)=O',
#  'C#CCC(C)C',
#  'CC(C)CC#N',
#  'C#CCC(C)O',
#  'CC(O)CC#N',
#  'CC(C)OC=O',
#  'CCOC(C)=O',
#  'CCOC(N)=O',
#  'CC(=O)C(C)=O',
#  'CC(=O)C(N)=O',
#  'NC(=O)C(N)=O',
#  'CC(=O)C(C)O',
#  'C#CC(=O)C#C',
#  'C#CC(=O)C#N',
#  'N#CC(=O)C#N',
#  'C#CC(=O)C=O',
#  'N#CC(=O)C=O',
#  'O=CC(=O)C=O',
#  'C#CC(C)C#C',
#  'C#CC(C)C#N',
#  'CC(C#N)C#N',
#  'C#CC(N)C#N',
#  'N#CC(N)C#N',
#  'C#CC(O)C#C',
#  'C#CC(O)C#N',
#  'N#CC(O)C#N',
#  'C#CC(C)C=O',
#  'CC(C#N)C=O',
#  'C#CC(O)C=O',
#  'N#CC(O)C=O',
#  'CC(C=O)C=O',
#  'CN(C=N)C=O',
#  'CN(C=O)C=O',
#  'O=CC(O)C=O',
#  'CN=C(N)C#N',
#  'CN=C(N)C=O',
#  'C#CC(=O)CC',
#  'CCC(=O)C#N',
#  'CNC(=N)C#N',
#  'C#CC(=O)NC',
#  'C#CC(=O)OC',
#  'COC(=O)C#N',
#  'C#CC(=O)CO',
#  'N#CC(=O)CO',
#  'CCC(=O)C=O',
#  'CNC(=N)C=O',
#  'CNC(=O)C=O',
#  'COC(=O)C=O',
#  'O=CC(=O)CO',
#  'CCC(=O)OC',
#  'CNC(=O)OC',
#  'COC(=O)CO',
#  'O=C(CO)CO',
#  'C#CC(C)CO',
#  'CC(C#N)CO',
#  'C#CC(C)CC',
#  'CCC(C)C#N',
#  'C#CC(O)CC',
#  'CCC(O)C#N',
#  'C#CC(C)OC',
#  'COC(C)C#N',
#  'N#CC(N)CO',
#  'N#CC(O)CN',
#  'C#CC(O)CO',
#  'N#CC(O)CO',
#  'O=CC(O)CO',
#  'C#CC#CC#C',
#  'C#CC#CC#N',
#  'N#CC#CC#N',
#  'C#CCCC#C',
#  'C#CCCC#N',
#  'N#CCCC#N',
#  'C#CC#CC=O',
#  'N#CC#CC=O',
#  'O=CC#CC=O',
#  'C#CCOC=N',
#  'N#CCOC=N',
#  'C#CCCC=O',
#  'N#CCCC=O',
#  'C#CCNC=O',
#  'N#CCNC=O',
#  'C#CCOC=O',
#  'N#CCOC=O',
#  'N=COCC=O',
#  'O=CCCC=O',
#  'O=CCNC=O',
#  'O=CCOC=O',
#  'CC#CC#CC',
#  'C#CCC#CC',
#  'CC#CCC#N',
#  'CC#CCC=O',
#  'CN=CNC=O',
#  'CN=COC=O',
#  'C#CC#CCC',
#  'CCC#CC#N',
#  'C#CC#CCO',
#  'N#CC#CCO',
#  'CCC#CC=O',
#  'O=CC#CCO',
#  'CCC#CCC',
#  'CCC#CCO',
#  'OCC#CCO',
#  'CC#CCCO',
#  'CC#CCCC',
#  'CC#CCOC',
#  'C#CCCCC',
#  'CCCCC#N',
#  'C#CCOCC',
#  'CCOCC#N',
#  'C#CCCOC',
#  'COCCC#N',
#  'C#CCCCO',
#  'N#CCCCO',
#  'CCCOC=O',
#  'O=COCCO',
#  'CC#CC(C)=NO',
#  'C#CCC(C)=NO',
#  'CC(CC#N)=NO',
#  'CC(CC=O)=NO',
#  'CC(=NO)C(N)=O',
#  'C#CC(C#C)=NO',
#  'C#CC(CC)=NO',
#  'C#CC(CO)=NO',
#  'C#CC(F)(F)F',
#  'N#CC(F)(F)F',
#  'O=CC(F)(F)F',
#  'OCC(F)(F)F',
#  'CCC(F)(F)F',
#  'CC#CC(C)(C)O',
#  'CC(C)(O)CC#N',
#  'CC(=N)NC(C)=O',
#  'CC(=N)NC(N)=O',
#  'CC(=N)OC(C)=O',
#  'CC(=N)OC(N)=O',
#  'CC(=O)CC(C)=O',
#  'CC(=O)CC(N)=O',
#  'CC(=O)NC(C)=O',
#  'CC(=O)NC(N)=O',
#  'NC(=O)CC(N)=O',
#  'NC(=O)NC(N)=O',
#  'C#CC(C)(C)C#C',
#  'C#CC(C)(C)C#N',
#  'CC(C)(C#N)C#N',
#  'C#CC(C)(N)C#N',
#  'CC(N)(C#N)C#N',
#  'C#CC(C)(O)C#C',
#  'C#CC(C)(O)C#N',
#  'CC(O)(C#N)C#N',
#  'C#CC(C)(C)C=O',
#  'CC(C)(C#N)C=O',
#  'C#CC(C)(O)C=O',
#  'CC(O)(C#N)C=O',
#  'CC(C)(C=O)C=O',
#  'CC(O)(C=O)C=O',
#  'CC(C)(C#N)CO',
#  'C#CC(C)(O)CO',
#  'CC(O)(C#N)CO',
#  'CCC(C)(O)C#N',
#  'COC(C)(C)C#N',
#  'CC#CCC(C)=O',
#  'CC#CCC(N)=O',
#  'CC#CCC(C)O',
#  'C#CC#CC(C)=O',
#  'CC(=O)C#CC#N',
#  'C#CC#CC(N)=O',
#  'N#CC#CC(N)=O',
#  'CC(=O)C#CC=O',
#  'NC(=O)C#CC=O',
#  'C#CCOC(C)=N',
#  'CC(=N)OCC#N',
#  'C#CCCC(C)=O',
#  'CC(=O)CCC#N',
#  'C#CCNC(C)=O',
#  'CC(=O)NCC#N',
#  'C#CCOC(C)=O',
#  'CC(=O)OCC#N',
#  'C#CCCC(N)=O',
#  'N#CCCC(N)=O',
#  'C#CCNC(N)=O',
#  'N#CCNC(N)=O',
#  'C#CCOC(N)=O',
#  'N#CCOC(N)=O',
#  'CC(=N)OCC=O',
#  'CC(=O)CCC=O',
#  'CC(=O)CNC=O',
#  'CC(=O)COC=N',
#  'CC(=O)COC=O',
#  'CC(=O)NCC=O',
#  'CC(=O)OCC=O',
#  'NC(=O)CCC=O',
#  'NC(=O)CNC=O',
#  'N=COCC(N)=O',
#  'NC(=O)COC=O',
#  'NC(=O)NCC=O',
#  'NC(=O)OCC=O',
#  'C#CC#CC(C)C',
#  'CC(C)C#CC#N',
#  'C#CC#CC(C)O',
#  'CC(O)C#CC#N',
#  'CC(C)C#CC=O',
#  'CC(O)C#CC=O',
#  'CC(C)OCC#N',
#  'CC(O)CCC#N',
#  'CN=CNC(C)=O',
#  'CN=CNC(N)=O',
#  'CN=COC(C)=O',
#  'CN=COC(N)=O',
#  'CC(=O)C#CCO',
#  'CCC#CC(C)=O',
#  'CCC#CC(N)=O',
#  'NC(=O)C#CCO',
#  'CC(O)C#CCO',
#  'CC(=O)OCCO',
#  'C#CCC(=O)C#C',
#  'C#CCC(=O)C#N',
#  'C#CC(=O)CC#N',
#  'N#CCC(=O)C#N',
#  'C#CCC(=O)C=O',
#  'N#CCC(=O)C=O',
#  'C#CC(=N)NC=O',
#  'C#CC(=N)OC=O',
#  'N#CC(=N)OC=O',
#  'N#CC(=N)NC=N',
#  'C#CC(=O)NC=N',
#  'C#CC(=O)OC=N',
#  'N#CC(=O)OC=N',
#  'C#CC(=O)NC=O',
#  'N=C(C=O)NC=O',
#  'N=C(C=O)OC=O',
#  'N=CNC(=N)C=O',
#  'N=CNC(=O)C=O',
#  'N=COC(=O)C=O',
#  'O=CNC(=O)C=O',
#  'C#CC(=O)C#CC',
#  'CC#CC(=O)C#N',
#  'CC#CC(=O)C=O',
#  'C#CC(C)C#CC',
#  'CC#CC(C)C#N',
#  'CC#CC(N)C#N',
#  'C#CC(O)C#CC',
#  'CC#CC(O)C#N',
#  'CC#CC(C)C=O',
#  'CC#CC(O)C=O',
#  'C#CCC(C)C#C',
#  'C#CCC(C)C#N',
#  'C#CC(C)CC#N',
#  'CC(C#N)CC#N',
#  'C#CCC(N)C#N',
#  'C#CC(N)CC#N',
#  'N#CCC(N)C#N',
#  'C#CCC(O)C#C',
#  'C#CCC(O)C#N',
#  'C#CC(O)CC#N',
#  'N#CCC(O)C#N',
#  'C#CCC(C)C=O',
#  'CC(C=O)CC#N',
#  'C#CCN(C)C=O',
#  'CN(C=O)CC#N',
#  'C#CCC(O)C=O',
#  'N#CCC(O)C=O',
#  'C#CC(C)CC=O',
#  'CC(C#N)CC=O',
#  'C#CC(C)NC=O',
#  'CC(C#N)NC=O',
#  'C#CC(C)OC=N',
#  'CC(C#N)OC=N',
#  'C#CC(C)OC=O',
#  'CC(C#N)OC=O',
#  'C#CC(O)CC=O',
#  'N#CC(O)CC=O',
#  'CC(C=O)CC=O',
#  'CC(C=O)NC=O',
#  'CC(C=O)OC=N',
#  'CC(C=O)OC=O',
#  'CN(C=O)CC=O',
#  'O=CCC(O)C=O',
#  'CN=C(C)NC=O',
#  'CN=C(C)OC=O',
#  'CN=C(N)NC=O',
#  'CN=CN(C)C=O',
#  'CC#CC(=O)CO',
#  'CC#CC(=O)CC',
#  'CC#CC(=O)NC',
#  'CC#CC(=O)OC',
#  'C#CCC(=O)CC',
#  'CCC(=O)CC#N',
#  'C#CCC(=O)NC',
#  'CNC(=O)CC#N',
#  'C#CCC(=O)OC',
#  'COC(=O)CC#N',
#  'C#CCC(=O)CO',
#  'N#CCC(=O)CO',
#  'CCC(=N)NC=O',
#  'CCC(=O)CC=O',
#  'CCC(=O)NC=N',
#  'CCC(=O)NC=O',
#  'CCC(=O)OC=N',
#  'CNC(=O)CC=O',
#  'CNC(=O)NC=N',
#  'CNC(=O)NC=O',
#  'CNC(=O)OC=N',
#  'COC(=N)NC=O',
#  'COC(=O)CC=O',
#  'COC(=O)NC=N',
#  'COC(=O)NC=O',
#  'NCC(=O)NC=O',
#  'N=COC(=O)CN',
#  'N=C(CO)NC=O',
#  'O=CCC(=O)CO',
#  'N=CNC(=O)CO',
#  'O=CNC(=O)CO',
#  'N=COC(=O)CO',
#  'CC#CC(O)CO',
#  'CC#CC(O)CC',
#  'CC(CO)CC#N',
#  'CCC(O)CC#N',
#  'COC(C)CC#N',
#  'C#CCC(O)CO',
#  'N#CCC(O)CO',
#  'CCN=C(N)C#N',
#  'CCN=C(N)C=O',
#  'C#CC(=O)CCC',
#  'CCCC(=O)C#N',
#  'CCNC(=N)C#N',
#  'C#CC(=O)NCC',
#  'C#CC(=N)OCC',
#  'CCOC(=N)C#N',
#  'C#CC(=O)OCC',
#  'CCOC(=O)C#N',
#  'CNCC(=O)C#N',
#  'C#CC(=O)COC',
#  'COCC(=O)C#N',
#  'C#CC(=O)CCO',
#  'N#CC(=O)CCO',
#  'CCCC(=O)C=O',
#  'CCNC(=O)C=O',
#  'CCOC(=N)C=O',
#  'CCOC(=O)C=O',
#  'COCC(=O)C=O',
#  'O=CC(=O)CCO',
#  'CCOC(=O)CO',
#  'COC(=O)CCO',
#  'CC(C#N)CCO',
#  'CCCC(O)C#N',
#  'CCOC(C)C#N',
#  'COCC(C)C#N',
#  'COCC(O)C#N',
#  'C#CC(O)CCO',
#  'N#CC(O)CCO',
#  'C#CC(=O)C(C)=O',
#  'CC(=O)C(=O)C#N',
#  'C#CC(=O)C(N)=O',
#  'CC(=O)C(=O)C=O',
#  'NC(=O)C(=O)C=O',
#  'C#CC(O)C(C)=O',
#  'CC(=O)C(O)C#N',
#  'C#CC(C)C(C)=O',
#  'C#CC(C)C(N)=O',
#  'CC(=O)C(C)C#N',
#  'CC(C#N)C(N)=O',
#  'C#CC(O)C(N)=O',
#  'N#CC(O)C(N)=O',
#  'C#CC(N)C(N)=O',
#  'N#CC(N)C(N)=O',
#  'C#CC(=O)C(C)C',
#  'CC(C)C(=O)C#N',
#  'C#CC(=O)C(C)O',
#  'CC(O)C(=O)C#N',
#  'CN(C)C(=N)C#N',
#  'C#CC(=O)N(C)C',
#  'CN(C)C(=O)C#N',
#  'CC(C)C(=O)C=O',
#  'CC(O)C(=O)C=O',
#  'CN(C)C(=O)C=O',
#  'CC(C)C(O)C#N',
#  'CC(O)C(C)C#N',
#  'C#CC(O)C(C)O',
#  'CC(O)C(O)C#N',
#  'CC(=O)C(O)C=O',
#  'CC(=O)C(C)C=O',
#  'CC(C=O)C(N)=O',
#  'CC(=O)N(C)C=N',
#  'CN(C=N)C(N)=O',
#  'CC(=N)N(C)C=O',
#  'CC(=O)N(C)C=O',
#  'CN(C=O)C(N)=O',
#  'NC(=O)C(O)C=O',
#  'CN=C(N)C(C)=O',
#  'CN=C(N)C(N)=O',
#  'CC(=O)C(=O)CO',
#  'CCC(=O)C(C)=O',
#  'CCC(=O)C(N)=O',
#  'CNC(=N)C(C)=O',
#  'CNC(=O)C(C)=O',
#  'CNC(=O)C(N)=O',
#  'COC(=O)C(C)=O',
#  'COC(=O)C(N)=O',
#  'NC(=O)C(=O)CO',
#  'COC(=O)C(C)O',
#  'C#CC(C#C)C#C',
#  'C#CC(C#C)C#N',
#  'C#CC(C#C)C=O',
#  'C#CC(C#N)C=O',
#  'N#CC(C#N)C=O',
#  'C#CC(C=O)C=O',
#  'N=CN(C=N)C=N',
#  'N=CN(C=N)C=O',
#  'N=CN(C=O)C=O',
#  'O=CN(C=O)C=O',
#  'CN=C(C#N)NC',
#  'C#CC(C#C)CC',
#  'C#CC(C#N)CC',
#  'CCC(C#N)C#N',
#  'C#CC(C#N)NC',
#  'CNC(C#N)C#N',
#  'C#CC(C#C)OC',
#  'C#CC(C#N)OC',
#  'COC(C#N)C#N',
#  'C#CC(C#C)CO',
#  'C#CC(C#N)CO',
#  'C#CC(C=O)CC',
#  'CCC(C#N)C=O',
#  'C#CC(C=O)NC',
#  'CNC(C#N)C=O',
#  'C#CC(C=O)OC',
#  'COC(C#N)C=O',
#  'C#CC(C=O)CO',
#  'N#CC(C=O)CO',
#  'CCC(C=O)C=O',
#  'CCN(C=N)C=O',
#  'CCN(C=O)C=O',
#  'CNC(C=O)C=O',
#  'COC(C=O)C=O',
#  'O=CC(C=O)CO',
#  'CCC(C#N)CO',
#  'CCC(C#N)OC',
#  'C#CC(CO)OC',
#  'COC(C#N)CO',
#  'C#CC(CO)CO',
#  'N#CC(CO)CO',
#  'C#CC#CCC#N',
#  'C#CC#CCC#C',
#  'C#CCC#CC#N',
#  'N#CC#CCC#N',
#  'C#CCCCC#C',
#  'C#CCCCC#N',
#  'C#CCNCC#N',
#  'C#CCOCC#C',
#  'C#CCOCC#N',
#  'N#CCCCC#N',
#  'N#CCNCC#N',
#  'N#CCOCC#N',
#  'C#CCC#CC=O',
#  'N#CCC#CC=O',
#  'C#CC#CCC=O',
#  'N#CC#CCC=O',
#  'O=CC#CCC=O',
#  'C#CCCOC=N',
#  'N#CCCOC=N',
#  'C#CCCCC=O',
#  'N#CCCCC=O',
#  'C#CCNCC=O',
#  'N#CCNCC=O',
#  'C#CCOCC=O',
#  'N#CCOCC=O',
#  'C#CCCNC=O',
#  'N#CCCNC=O',
#  'C#CCCOC=O',
#  'N#CCCOC=O',
#  'N=COCCC=O',
#  'O=CCCCC=O',
#  'O=CCCNC=O',
#  'O=CCCOC=O',
#  'O=CCNCC=O',
#  'O=CCOCC=O',
#  'C#CC#CC#CC',
#  'CC#CC#CC#N',
#  'CC#CC#CC=O',
#  'CC#CCC#CC',
#  'C#CCCC#CC',
#  'CC#CCCC#N',
#  'CC#CCCC=O',
#  'CC#CCNC=O',
#  'CC#CCOC=N',
#  'CC#CCOC=O',
#  'C#CCOC=NC',
#  'CN=COCC#N',
#  'CN=COCC=O',
#  'CC#CC#CCO',
#  'CC#CC#CCC',
#  'C#CCC#CCC',
#  'CCC#CCC#N',
#  'C#CCC#CCO',
#  'N#CCC#CCO',
#  'CCC#CCC=O',
#  'O=CCC#CCO',
#  'C#CCN=COC',
#  'COC=NCC#N',
#  'CCN=CNC=O',
#  'CCN=COC=O',
#  'COC=NCC=O',
#  'C#CC#CCCC',
#  'CCCC#CC#N',
#  'C#CC#CCOC',
#  'COCC#CC#N',
#  'C#CC#CCCO',
#  'N#CC#CCCO',
#  'CCCC#CC=O',
#  'COCC#CC=O',
#  'O=CC#CCCO',
#  'OCC#CCCO',
#  'CCCOCC#N',
#  'CCOCCC#N',
#  'COCCCC#N',
#  'N#CCCCCO',
#  'C#CCOCCO',
#  'N#CCOCCO',
#  'CC#CCC(C)=NO',
#  'C#CC#CC(C)=NO',
#  'CC(C#CC#N)=NO',
#  'CC(C#CC=O)=NO',
#  'C#CCCC(C)=NO',
#  'CC(CCC#N)=NO',
#  'CC(COC=O)=NO',
#  'CC(C#CCO)=NO',
#  'CCC#CC(C)=NO',
#  'C#CCC(C#C)=NO',
#  'C#CC(CC#N)=NO',
#  'C#CC(CC=O)=NO',
#  'C#CC(C#CC)=NO',
#  'CC#CC(CO)=NO',
#  'CC#CC(CC)=NO',
#  'C#CCC(CC)=NO',
#  'CCC(CC#N)=NO',
#  'C#CC(CCC)=NO',
#  'C#CC(COC)=NO',
#  'C#CC(CCO)=NO',
#  'C#CC(=NO)C(C)=NO',
#  'C#CC(C)C(C)=NO',
#  'CC(=NO)C(C)C#N',
#  'C#CC(=NO)C(C)C',
#  'C#CC(=NO)C(C)O',
#  'CC#CC(F)(F)F',
#  'C#CCC(F)(F)F',
#  'N#CCC(F)(F)F',
#  'O=CCC(F)(F)F',
#  'OCCC(F)(F)F',
#  'CC(=O)C(F)(F)F',
#  'CC(O)C(F)(F)F',
#  'CC(C)(O)C(O)C#N',
#  'C#CC(=O)C(C)(C)C',
#  'CC(C)(C)C(=O)C#N',
#  'C#CC(=O)C(C)(C)O',
#  'CC(C)(O)C(=O)C#N',
#  'CC(C)(C)C(=O)C=O',
#  'CC(C)(O)C(=O)C=O',
#  'C#CC#CC(C)(C)C',
#  'CC(C)(C)C#CC#N',
#  'C#CC#CC(C)(C)O',
#  'CC(C)(O)C#CC#N',
#  'CC(C)(C)C#CC=O',
#  'CC(C)(O)C#CC=O',
#  'C#CC(C)(C)C#CC',
#  'CC#CC(C)(C)C#N',
#  'CC#CC(C)(N)C#N',
#  'C#CC(C)(O)C#CC',
#  'CC#CC(C)(O)C#N',
#  'CC#CC(C)(C)C=O',
#  'CC#CC(C)(O)C=O',
#  'C#CCC(C)(C)C#C',
#  'C#CCC(C)(C)C#N',
#  'C#CC(C)(C)CC#N',
#  'CC(C)(C#N)CC#N',
#  'C#CCC(C)(N)C#N',
#  'C#CC(C)(N)CC#N',
#  'CC(N)(C#N)CC#N',
#  'C#CCC(C)(O)C#C',
#  'C#CCC(C)(O)C#N',
#  'C#CC(C)(O)CC#N',
#  'CC(O)(C#N)CC#N',
#  'C#CCC(C)(C)C=O',
#  'CC(C)(C=O)CC#N',
#  'C#CCC(C)(O)C=O',
#  'CC(O)(C=O)CC#N',
#  'C#CC(C)(C)CC=O',
#  'CC(C)(C#N)CC=O',
#  'C#CC(C)(C)NC=O',
#  'CC(C)(C#N)NC=O',
#  'C#CC(C)(C)OC=N',
#  'CC(C)(C#N)OC=N',
#  'C#CC(C)(C)OC=O',
#  'CC(C)(C#N)OC=O',
#  'C#CC(C)(O)CC=O',
#  'CC(O)(C#N)CC=O',
#  'CC(C)(C=O)CC=O',
#  'CC(C)(C=O)NC=O',
#  'CC(C)(C=O)OC=N',
#  'CC(C)(C=O)OC=O',
#  'CC(O)(C=O)CC=O',
#  'CC(O)(CO)CC#N',
#  'CC(O)(C#N)CCO',
#  'C#CC(C)(C)C(C)=O',
#  'CC(=O)C(C)(C)C#N',
#  'C#CC(C)(O)C(C)=O',
#  'CC(=O)C(C)(O)C#N',
#  'C#CC(C)(C)C(N)=O',
#  'CC(C)(C#N)C(N)=O',
#  'CC(N)(C#N)C(N)=O',
#  'C#CC(C)(O)C(N)=O',
#  'CC(O)(C#N)C(N)=O',
#  'CC(=O)C(C)(C)C=O',
#  'CC(=O)C(C)(O)C=O',
#  'CC(C)(C=O)C(N)=O',
#  'CC(O)(C=O)C(N)=O',
#  'CC(O)C(C)(O)C#N',
#  'CC(=O)C#CC(C)=O',
#  'CC(=O)C#CC(N)=O',
#  'NC(=O)C#CC(N)=O',
#  'CC(=N)OCC(C)=O',
#  'CC(=O)CCC(C)=O',
#  'CC(=O)CCC(N)=O',
#  'CC(=O)CNC(C)=O',
#  'CC(=O)CNC(N)=O',
#  'CC(=O)COC(C)=O',
#  'CC(=O)COC(N)=O',
#  'CC(=O)NCC(N)=O',
#  'CC(=O)OCC(N)=O',
#  'NC(=O)CCC(N)=O',
#  'NC(=O)CNC(N)=O',
#  'NC(=O)COC(N)=O',
#  'CC(=O)C#CC(C)C',
#  'CC(C)C#CC(N)=O',
#  'CC(=O)C#CC(C)O',
#  'CC(O)C#CC(N)=O',
#  'C#CC(=O)NC(C)=N',
#  'C#CC(=O)OC(C)=N',
#  'CC(=N)OC(=O)C#N',
#  'C#CC(=O)CC(C)=O',
#  'C#CC(=N)NC(C)=O',
#  'C#CC(=O)NC(C)=O',
#  'C#CC(=O)CC(N)=O',
#  'C#CC(=N)NC(N)=O',
#  'C#CC(=O)NC(N)=O',
#  'CC(=N)NC(=O)C=O',
#  'CC(=N)OC(=O)C=O',
#  'CC(=O)NC(=N)C=O',
#  'CC(=O)NC(=O)C=O',
#  'N=C(C=O)NC(N)=O',
#  'NC(=O)NC(=O)C=O',
#  'CC(C)N=C(N)C#N',
#  'C#CC(=O)CC(C)C',
#  'CC(C)CC(=O)C#N',
#  'CC(C)NC(=N)C#N',
#  'C#CC(=O)NC(C)C',
#  'C#CC(=O)OC(C)C',
#  'CC(C)OC(=O)C#N',
#  'C#CC(=O)CC(C)O',
#  'CC(O)CC(=O)C#N',
#  'C#CC(=O)CN(C)C',
#  'CN(C)CC(=O)C#N',
#  'CC(C)CC(=O)C=O',
#  'CC(C)NC(=O)C=O',
#  'CC(C)OC(=O)C=O',
#  'CC(O)CC(=O)C=O',
#  'CC(O)CC(O)C#N',
#  'C#CC(O)CC(C)=O',
#  'CC(=O)CC(O)C#N',
#  'C#CC(C)CC(C)=O',
#  'CC(=O)CC(C)C#N',
#  'C#CC(C)CC(N)=O',
#  'CC(C#N)CC(N)=O',
#  'C#CC(C)NC(C)=O',
#  'CC(=O)NC(C)C#N',
#  'C#CC(C)NC(N)=O',
#  'CC(C#N)NC(N)=O',
#  'C#CC(C)OC(C)=O',
#  'CC(=O)OC(C)C#N',
#  'C#CC(C)OC(N)=O',
#  'CC(C#N)OC(N)=O',
#  'C#CC(O)CC(N)=O',
#  'N#CC(O)CC(N)=O',
#  'N#CC(N)CC(N)=O',
#  'CC(=O)CC(O)C=O',
#  'CC(=O)CC(C)C=O',
#  'CC(C=O)CC(N)=O',
#  'CC(=O)NC(C)C=O',
#  'CC(C=O)NC(N)=O',
#  'CC(=O)OC(C)C=O',
#  'CC(C=O)OC(N)=O',
#  'CC(=O)CN(C)C=O',
#  'CN(C=O)CC(N)=O',
#  'NC(=O)CC(O)C=O',
#  'CN=C(C)OC(C)=O',
#  'CN=C(C)OC(N)=O',
#  'CC(=N)NC(=O)CO',
#  'CC(=O)CC(=O)CO',
#  'CC(=O)NC(=N)CO',
#  'CC(=O)NC(=O)CN',
#  'CC(=O)NC(=O)CO',
#  'CCC(=O)CC(C)=O',
#  'CCC(=O)CC(N)=O',
#  'CCC(=O)NC(C)=O',
#  'CCC(=O)NC(N)=O',
#  'CNC(=O)CC(C)=O',
#  'CNC(=O)CC(N)=O',
#  'CNC(=O)NC(C)=O',
#  'CNC(=O)NC(N)=O',
#  'COC(=N)NC(C)=O',
#  'COC(=N)NC(N)=O',
#  'COC(=O)CC(C)=O',
#  'COC(=O)CC(N)=O',
#  'COC(=O)NC(C)=N',
#  'COC(=O)NC(C)=O',
#  'COC(=O)NC(N)=O',
#  'NC(=O)CC(=O)CO',
#  'N=C(CO)NC(N)=O',
#  'NC(=O)NC(=O)CO',
#  'NCC(=O)NC(N)=O',
#  'CC#CC#CC(C)=O',
#  'CC#CC#CC(N)=O',
#  'CC#CC#CC(C)C',
#  'CC#CC#CC(C)O',
#  'CC#CCCC(C)=O',
#  'CC#CCCC(N)=O',
#  'CC#CCNC(C)=O',
#  'CC#CCNC(N)=O',
#  'CC#CCOC(C)=O',
#  'CC#CCOC(N)=O',
#  'C#CCC#CC(C)=O',
#  'CC(=O)C#CCC#N',
#  'C#CCC#CC(N)=O',
#  'N#CCC#CC(N)=O',
#  'CC(=O)C#CCC=O',
#  'NC(=O)C#CCC=O',
#  'C#CC#CCC(C)=O',
#  'CC(=O)CC#CC#N',
#  'C#CC#CCC(N)=O',
#  'N#CC#CCC(N)=O',
#  'CC(=O)CC#CC=O',
#  'NC(=O)CC#CC=O',
#  'C#CCCOC(C)=N',
#  'CC(=N)OCCC#N',
#  'C#CCCCC(C)=O',
#  'CC(=O)CCCC#N',
#  'CC(=O)CNCC#N',
#  'C#CCOCC(C)=O',
#  'CC(=O)COCC#N',
#  'C#CCCNC(C)=O',
#  'CC(=O)NCCC#N',
#  'C#CCCOC(C)=O',
#  'CC(=O)OCCC#N',
#  'C#CCCCC(N)=O',
#  'N#CCCCC(N)=O',
#  'N#CCNCC(N)=O',
#  'C#CCOCC(N)=O',
#  'N#CCOCC(N)=O',
#  'C#CCCNC(N)=O',
#  'N#CCCNC(N)=O',
#  'C#CCCOC(N)=O',
#  'N#CCCOC(N)=O',
#  'CC(=N)OCCC=O',
#  'CC(=O)CCCC=O',
#  'CC(=O)CCNC=O',
#  'CC(=O)CCOC=N',
#  'CC(=O)CCOC=O',
#  'CC(=O)CNCC=O',
#  'CC(=O)COCC=O',
#  'CC(=O)NCCC=O',
#  'CC(=O)OCCC=O',
#  'NC(=O)CCCC=O',
#  'NC(=O)CCNC=O',
#  'N=COCCC(N)=O',
#  'NC(=O)CCOC=O',
#  'NC(=O)CNCC=O',
#  'NC(=O)COCC=O',
#  'NC(=O)NCCC=O',
#  'NC(=O)OCCC=O',
#  'C#CCC#CC(C)C',
#  'CC(C)C#CCC#N',
#  'C#CCC#CC(C)O',
#  'CC(O)C#CCC#N',
#  'CC(C)C#CCC=O',
#  'CC(O)C#CCC=O',
#  'CC(C)N=COC=O',
#  'C#CC#CCC(C)C',
#  'CC(C)CC#CC#N',
#  'C#CC#CCC(C)O',
#  'CC(O)CC#CC#N',
#  'CN(C)CC#CC#N',
#  'CC(C)CC#CC=O',
#  'CC(O)CC#CC=O',
#  'CN(C)CC#CC=O',
#  'CN=COCC(C)=O',
#  'CN=COCC(N)=O',
#  'CC(=O)CC#CCO',
#  'CCC#CCC(C)=O',
#  'CCC#CCC(N)=O',
#  'NC(=O)CC#CCO',
#  'CCN=COC(C)=O',
#  'CCN=COC(N)=O',
#  'COC=NCC(C)=O',
#  'COC=NCC(N)=O',
#  'CC(=O)C#CCCO',
#  'CCCC#CC(C)=O',
#  'CCCC#CC(N)=O',
#  'COCC#CC(C)=O',
#  'COCC#CC(N)=O',
#  'NC(=O)C#CCCO',
#  'C#CCC(=O)CC#C',
#  'C#CCC(=O)CC#N',
#  'N#CCC(=O)CC#N',
#  'C#CCC(=N)NC=O',
#  'C#CCC(=N)OC=O',
#  'N#CCC(=N)NC=O',
#  'N#CCC(=N)OC=O',
#  'C#CCC(=O)NC=N',
#  'N#CCC(=O)NC=N',
#  'C#CCC(=O)OC=N',
#  'N#CCC(=O)OC=N',
#  'C#CCC(=O)CC=O',
#  'C#CCC(=O)NC=O',
#  'N#CCC(=O)NC=O',
#  'N=C(CC=O)NC=O',
#  'N=C(CC=O)OC=O',
#  'N=C(NC=O)NC=O',
#  'N=CNC(=O)CC=O',
#  'N=CNC(=O)NC=N',
#  'N=CNC(=O)NC=O',
#  'N=CNC(=O)OC=N',
#  'N=COC(=O)CC=O',
#  'N=COC(=O)NC=O',
#  'O=CCC(=O)CC=O',
#  'O=CCC(=O)NC=O',
#  'O=CNC(=O)NC=O',
#  'CC#CC(=O)C#CC',
#  'C#CCC(=O)C#CC',
#  'CC#CC(=O)CC#N',
#  'CC#CC(=N)NC=O',
#  'CC#CC(=N)OC=O',
#  'CC#CC(=O)NC=N',
#  'CC#CC(=O)NC=O',
#  'CC#CC(=O)OC=N',
#  'CC#CC(C)C#CC',
#  'CC#CC(O)C#CC',
#  'C#CCC(C)C#CC',
#  'CC#CC(C)CC#N',
#  'CC#CC(N)CC#N',
#  'C#CCC(O)C#CC',
#  'CC#CC(O)CC#N',
#  'CC#CC(C)CC=O',
#  'CC#CC(C)NC=O',
#  'CC#CC(C)OC=N',
#  'CC#CC(C)OC=O',
#  'CC#CC(O)CC=O',
#  'C#CCC(C)CC#C',
#  'C#CCC(C)CC#N',
#  'CC(CC#N)CC#N',
#  'C#CCN(C)CC#N',
#  'CN(CC#N)CC#N',
#  'N#CCC(N)CC#N',
#  'C#CCC(O)CC#C',
#  'C#CCC(O)CC#N',
#  'N#CCC(O)CC#N',
#  'C#CCC(C)NC=O',
#  'C#CCC(C)OC=N',
#  'C#CCC(C)OC=O',
#  'CC(CC#N)NC=O',
#  'CC(CC#N)OC=N',
#  'CC(CC#N)OC=O',
#  'C#CCC(C)CC=O',
#  'CC(CC#N)CC=O',
#  'C#CCN(C)CC=O',
#  'CN(CC#N)CC=O',
#  'C#CCC(O)CC=O',
#  'N#CCC(O)CC=O',
#  'CC(CC=O)CC=O',
#  'CC(CC=O)NC=O',
#  'CC(CC=O)OC=N',
#  'CC(CC=O)OC=O',
#  'O=CCC(O)CC=O',
#  'CC#CC(=O)CCO',
#  'CC#CC(=O)CCC',
#  'CC#CC(=O)NCC',
#  'CC#CC(=N)OCC',
#  'CC#CC(=O)OCC',
#  'CC#CC(=O)COC',
#  'C#CCC(=O)CCC',
#  'CCCC(=O)CC#N',
#  'C#CCC(=O)NCC',
#  'CCNC(=O)CC#N',
#  'C#CCC(=N)OCC',
#  'CCOC(=N)CC#N',
#  'C#CCC(=O)OCC',
#  'CCOC(=O)CC#N',
#  'C#CCC(=O)COC',
#  'COCC(=O)CC#N',
#  'C#CCC(=O)CCO',
#  'N#CCC(=O)CCO',
#  'CCCC(=N)OC=O',
#  'CCCC(=O)CC=O',
#  'CCCC(=O)NC=O',
#  'CCCC(=O)OC=N',
#  'CCNC(=O)CC=O',
#  'CCNC(=O)NC=O',
#  'CCNC(=O)OC=N',
#  'CCOC(=N)CC=O',
#  'CCOC(=N)NC=O',
#  'CCOC(=O)CC=O',
#  'CCOC(=O)NC=N',
#  ...]

# %%
# Remove no-ring molecules from qm9_dict
for smi in no_ring:
    qm9_dict.pop(smi, None)
len(qm9_dict)
# Out:
# 17546

# %% [markdown]
# ## 6. Remove molecules that failed the RDKit embedding method using the srETKDGv3 algorithm.

# %%
# Find molecules that fail for rdkit embedding
embed_fail = list()
for gdb_smi in tqdm(qm9_dict):
    mol = Chem.MolFromSmiles(gdb_smi)
    mol = Chem.AddHs(mol)
    params = Chem.rdDistGeom.srETKDGv3()
    params.randomSeed = 0xf00d
    params.clearConfs = True
    
    if (AllChem.EmbedMolecule(mol, params=params)) == -1:
        print(gdb_smi)
        embed_fail.append(gdb_smi)
# Out:
#   0%|          | 0/17546 [00:00<?, ?it/s]
# N#CC12CCC1C(=O)O2
# C#CC12COC1C(=O)O2
# N#CC12COC1C(=O)O2
# N#CC1CC2C(=O)OC12
# C#CC1OC2C(=O)OC12
# N#CC1OC2C(=O)OC12
# N#CC1CC2OC(=O)C12
# N#CC12CCC1OC2=O
# C#CC12OCC1OC2=O
# N#CC12OCC1OC2=O

# %%
# Remove embedding failing molecules from qm9_dict
for smi in embed_fail:
    qm9_dict.pop(smi, None)
len(qm9_dict)
# Out:
# 17536

# %% [markdown]
# ## 7. Remove molecules having bond(s) broken or rearrangement reactions after reorganization energy calculations described in the manuscript.

# %%
# This function was run after DFT optimizations were done
# origin_smi: original smiles string, geom_after_opt: geometry after DFT optimization in XYZ format
def graph_check(origin_smi, geom_after_opt):
    g1 = read_smiles(origin_smi, explicit_hydrogen=True)
    g1_noH = read_smiles(origin_smi)
    try:
        smi = pybel.readstring('xyz',geom_after_opt).write('smi').strip()
        if '.' in smi:
            return origin_smi
        g2 = read_smiles(smi, explicit_hydrogen=True)
        g2_noH = read_smiles(smi)
    except:
        return origin_smi
    
    if (not nx.is_isomorphic(g1,g2)) or (not nx.is_isomorphic(g1_noH,g2_noH, node_match=lambda n1,n2:n1['hcount']==n2['hcount'])):
        return origin_smi
    else:
        return False
